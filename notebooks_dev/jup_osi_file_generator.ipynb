# %% [markdown]
# ## Import Files

# %%
from mstr_robotics._paths import REPO_ROOT, USER_CONFIG, OSI_FILES, OSI_SCHEMA, OSI_DASHBOARD_CONTEXT, MCP_DATA, PYTHON_IO
import pandas as pd
import numpy as np
import json
from mstr_robotics.mstr_classes import get_conn
from mstr_robotics.osi_exporter import export_dashboard
from mstr_robotics.dossier import DossReadOut, DossReadOutDet
with open('..\\config\\user_d.json', 'r', encoding='utf-8') as openfile:
    user_d = json.load(openfile)

with open(OSI_SCHEMA, 'r', encoding='utf-8') as openfile:
    osi_dashboard_schema_d = json.load(openfile)

# %%
from mstr_robotics._paths import REPO_ROOT, USER_CONFIG, OSI_FILES, OSI_SCHEMA, OSI_DASHBOARD_CONTEXT, MCP_DATA, PYTHON_IO
conn_params = user_d["conn_params"]
conn = get_conn(**conn_params)
conn.headers['Content-type'] = "application/json"

i_doss_read_out     = DossReadOut()
i_doss_read_out_det = DossReadOutDet()
conn.select_project(user_d["conn_params"]["project_id"])

#object ids are maintained in ..\config\jupyter_objects_d.json
with open("..\\config\\jupyter_objects_d.json", "r") as openfile:
    jupyter_objects_d = json.load(openfile)
nb_d = jupyter_objects_d["jup_osi_file_generator"]

dossier_id_l = nb_d["misc"]["dossier_id_l"]

for doss_id in dossier_id_l:
    osi_d       = export_dashboard.build_osi_semantic_model(conn, doss_id)
    doss_hier_l = i_doss_read_out_det.run_read_out_doss_hier_det(conn, [doss_id])
    filt_sel_d  = i_doss_read_out.run_read_out_doss_filt_sel(conn, [doss_id])

    osi_d["dashboards"] = export_dashboard.build_osi_dashboard(
        doss_hier_l=doss_hier_l,
        filt_sel_d=filt_sel_d,
        semantic_model_name=doss_id,   # ID matches semantic_model name
    )

    out_path = str(OSI_FILES / f"osi_dashboard_{doss_id}.yml")
    osi_yaml=export_dashboard.osi_yaml_dump(osi_d, out_path)
    print(f"Written → {out_path}")


osi_d

# %%
from mstr_robotics._paths import REPO_ROOT, USER_CONFIG, OSI_FILES, OSI_SCHEMA, OSI_DASHBOARD_CONTEXT, MCP_DATA, PYTHON_IO
ai_context_d={}
ai_sys_dashbaord_prp=""
ai_sys_dashbaord_prp += "Within the dashboard you find URI to Onotologies of Brands and Artists"
ai_sys_dashbaord_prp += "Please consider this information when answering the questions of the user"


#ai_context_d["dashboard_prp"] = ai_sys_dashbaord_prp
ai_context_d["rag_files"] = [str(OSI_DASHBOARD_CONTEXT / "*")]
ai_context_d["grid_ontologies"] = []
osi_d=export_dashboard.add_ai_context(
    osi_d      = osi_d,
    path       = "dashboards",
    ai_context = json.dumps(ai_context_d),
    out_path   = str(OSI_FILES / f"osi_dashboard_{doss_id}.yml"),
)


out_path = str(OSI_FILES / f"osi_dashboard_{doss_id}.yml")
osi_yaml=export_dashboard.osi_yaml_dump(osi_d, out_path)
print(f"Written → {out_path}")


osi_d
# Out:
# [ai_context @ dashboards] Written → c:\coding\Python_environments\OSI_Files\osi_dashboard_8D47320148C7E2850BFD2B9605D73297.yml
# Written → c:\coding\Python_environments\OSI_Files\osi_dashboard_8D47320148C7E2850BFD2B9605D73297.yml
# {'version': '0.2.0',
#  'semantic_model': [{'name': '8D47320148C7E2850BFD2B9605D73297', 'datasets': [{'name': '742F452F43CE8C06BDFA34A265AB2E09', 'source': '742F452F43CE8C06BDFA34A265AB2E09', 'fields': [{'name': '8D679D3B11D3E4981000E787EC6DE8A4@A73FB8C84685F946990E0ABB4CD34123', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '8D679D3B11D3E4981000E787EC6DE8A4@A73FB8C84685F946990E0ABB4CD34123'}]}}, {'name': '8D679D3B11D3E4981000E787EC6DE8A4@FE96F95744D713DEA402A69576E7C1DA', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '8D679D3B11D3E4981000E787EC6DE8A4@FE96F95744D713DEA402A69576E7C1DA'}]}}, {'name': '8D679D3B11D3E4981000E787EC6DE8A4@CCFBE2A5EADB4F50941FB879CCF1721C', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '8D679D3B11D3E4981000E787EC6DE8A4@CCFBE2A5EADB4F50941FB879CCF1721C'}]}}, {'name': '8D679D3B11D3E4981000E787EC6DE8A4@45C11FA478E745FEA08D781CEA190FE5', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '8D679D3B11D3E4981000E787EC6DE8A4@45C11FA478E745FEA08D781CEA190FE5'}]}}, {'name': '8D679D4111D3E4981000E787EC6DE8A4@CCFBE2A5EADB4F50941FB879CCF1721C', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '8D679D4111D3E4981000E787EC6DE8A4@CCFBE2A5EADB4F50941FB879CCF1721C'}]}}, {'name': 'D40E5ACA409A88F64BDE4FB2B29646E9@CCFBE2A5EADB4F50941FB879CCF1721C', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': 'D40E5ACA409A88F64BDE4FB2B29646E9@CCFBE2A5EADB4F50941FB879CCF1721C'}]}}, {'name': '54BABD9E11D59D57C000B28A4CC5F24F@61627D4A4DD96CC4EF1A319AEE91207A', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '54BABD9E11D59D57C000B28A4CC5F24F@61627D4A4DD96CC4EF1A319AEE91207A'}]}}, {'name': '54BABD9E11D59D57C000B28A4CC5F24F@73C058A9458CBA6FA43828B8CC81ED93', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '54BABD9E11D59D57C000B28A4CC5F24F@73C058A9458CBA6FA43828B8CC81ED93'}]}}, {'name': '54BABD9E11D59D57C000B28A4CC5F24F@45C11FA478E745FEA08D781CEA190FE5', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '54BABD9E11D59D57C000B28A4CC5F24F@45C11FA478E745FEA08D781CEA190FE5'}]}}, {'name': '846E77494CAFEAAC43BA51986F6EBCBF@CCFBE2A5EADB4F50941FB879CCF1721C', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '846E77494CAFEAAC43BA51986F6EBCBF@CCFBE2A5EADB4F50941FB879CCF1721C'}]}}, {'name': '8D679D3A11D3E4981000E787EC6DE8A4@45C11FA478E745FEA08D781CEA190FE5', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '8D679D3A11D3E4981000E787EC6DE8A4@45C11FA478E745FEA08D781CEA190FE5'}]}}, {'name': '8D679D3A11D3E4981000E787EC6DE8A4@CCFBE2A5EADB4F50941FB879CCF1721C', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '8D679D3A11D3E4981000E787EC6DE8A4@CCFBE2A5EADB4F50941FB879CCF1721C'}]}}, {'name': '8D679D3511D3E4981000E787EC6DE8A4@45C11FA478E745FEA08D781CEA190FE5', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '8D679D3511D3E4981000E787EC6DE8A4@45C11FA478E745FEA08D781CEA190FE5'}]}}, {'name': '8D679D3511D3E4981000E787EC6DE8A4@CCFBE2A5EADB4F50941FB879CCF1721C', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '8D679D3511D3E4981000E787EC6DE8A4@CCFBE2A5EADB4F50941FB879CCF1721C'}]}}, {'name': '8D679D3511D3E4981000E787EC6DE8A4@F738C38C49CDBB45E222948442952C89', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '8D679D3511D3E4981000E787EC6DE8A4@F738C38C49CDBB45E222948442952C89'}]}}, {'name': '8D679D3511D3E4981000E787EC6DE8A4@A192356B4E9B627594BA11BBEA0754B9', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '8D679D3511D3E4981000E787EC6DE8A4@A192356B4E9B627594BA11BBEA0754B9'}]}}, {'name': '8D679D3711D3E4981000E787EC6DE8A4@CCFBE2A5EADB4F50941FB879CCF1721C', 'expression': {'dialects': [{'dialect': 'MSTR_ROBOTICS', 'expression': '8D679D3711D3E4981000E787EC6DE8A4@CCFBE2A5EADB4F50941FB879CCF1721C'}]}}, {'name': '8D679D3711D3E4981000E787EC6DE8A4@45C ...
#  'dashboards': [{'name': '8D47320148C7E2850BFD2B9605D73297', 'ai_context': '{"rag_files": ["c:\\\\coding\\\\Python_environments\\\\OSI_Files\\\\Dashboard_Context\\\\*"], "grid_ontologies": []}', 'semantic_model': '8D47320148C7E2850BFD2B9605D73297', 'chapters': [{'name': 'K36', 'pages': [{'name': 'W63', 'visualizations': [{'name': 'K56', 'type': 'custom', 'dimensions': [{'name': '8D679D3B11D3E4981000E787EC6DE8A4@CCFBE2A5EADB4F50941FB879CCF1721C', 'type': 'field'}, {'name': '8D679D3B11D3E4981000E787EC6DE8A4@CCFBE2A5EADB4F50941FB879CCF1721C', 'type': 'field'}, {'name': '54BABECD11D59D57C000B28A4CC5F24F@CCFBE2A5EADB4F50941FB879CCF1721C', 'type': 'field'}, {'name': '54BABECD11D59D57C000B28A4CC5F24F@CC6D54B741FB7A8A8167AFB11455B829', 'type': 'field'}, {'name': '54BABECD11D59D57C000B28A4CC5F24F@A6BEF0F34AF242A8F42410887888AB22', 'type': 'field'}, {'name': '54BABECD11D59D57C000B28A4CC5F24F@CCFBE2A5EADB4F50941FB879CCF1721C', 'type': 'field'}, {'name': '54BABECD11D59D57C000B28A4CC5F24F@CC6D54B741FB7A8A8167AFB11455B829', 'type': 'field'}, {'name': '54BABECD11D59D57C000B28A4CC5F24F@A6BEF0F34AF242A8F42410887888AB22', 'type': 'field'}], 'metrics': [{'name': '4C051DB611D3E877C000B3B2D86C964F', 'type': 'metric'}, {'name': '838367154BDAFF3F783D0EB5CD82386A', 'type': 'metric'}, {'name': '4C05177011D3E877C000B3B2D86C964F', 'type': 'metric'}, {'name': '4C05199311D3E877C000B3B2D86C964F', 'type': 'metric'}, {'name': '7FD5B69611D5AC76C000D98A4CC5F24F', 'type': 'metric'}, {'name': 'CC10F9A14CA79466D5BE2AB86FF45865', 'type': 'metric'}]}, {'name': 'K57', 'type': 'custom', 'dimensions': [{'name': '6E069EA411D3E4E41000E887EC6DE8A4@45C11FA478E745FEA08D781CEA190FE5', 'type': 'field'}, {'name': '6E069EA411D3E4E41000E887EC6DE8A4@45C11FA478E745FEA08D781CEA190FE5', 'type': 'field'}], 'metrics': [{'name': '7FD5B69611D5AC76C000D98A4CC5F24F', 'type': 'metric'}, {'name': 'CC10F9A14CA79466D5BE2AB86FF45865', 'type': 'metric'}, {'name': '838367154BDAFF3F783D0EB5CD82386A', 'type': 'metric'}, {'name': '4C051DB611D3E877C000B3B2D86C964F', 'type': 'metric'}, {'name': '4C05199311D3E877C000B3B2D86C964F', 'type': 'metric'}]}]}]}]}]}
