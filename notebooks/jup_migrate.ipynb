# %% [markdown]
# # MicroStrateg(P)ython Migration

# %% [markdown]
# ## Load libraries

# %%
import json
from mstrio.object_management import folder
import pandas as pd
from time import sleep
import shutil
import os
from mstrio.connection import Connection
from mstrio.object_management.migration import (
    PackageType,
    Migration,
    PackageConfig,
    PackageSettings
)

from mstrio.object_management.migration.package import (
    Action,
    ImportStatus,
    PackageStatus,
    ValidationStatus,
)



def bld_mig_list_from_sh_fold(conn, folder_id,action= "USE_EXISTING",include_dependents= False ):

    #obj_l = get_folder_obj_l(conn=conn, folder_id=folder_id)
    i_folder = folder.Folder(connection=conn, id=folder_id)
    obj_l = i_folder.get_contents(to_dictionary=True)
    
    obj_det_l=[]
    for obj_d in obj_l:
        #print(obj_d)
        if obj_d["type"] == 18:
            obj_det_d = {}
            obj_det_d["id"] = obj_d["target_info"]["id"]
            obj_det_d["type"] = obj_d["target_info"]["type"]
            obj_det_d["action"] = action
            obj_det_d["include_dependents"] = include_dependents
            obj_det_d["subtype"] = obj_d["target_info"]["subtype"] # only for read out object definition (see end of note book)
            obj_det_l.append(obj_det_d.copy())  

    return obj_det_l

# %% [markdown]
# ## Configure Migration

# %%
#define Package
usr_migration_folder_name="Daniel_Migration"
usr_package_folder_name="20250223_demo"


short_cut_folder_id="9316DEEE4820CF81E80157855D37711B"

# Connect Projects
with open('..\\config\\user_d.json', 'r') as openfile:
    user_d = json.load(openfile)

#set user credentials and open a connection to the i-server
username = user_d["username"]
password =user_d["password"]
base_url= user_d["base_url"]

source_username=username
source_password=password
source_base_url=base_url

target_username=username
target_password=password
target_base_url=base_url

source_project_id="B7CA92F04B9FAE8D941C3E9B7E0CD754"
target_project_id="40DA7A1549651FD60A9D39AAB7EC77B0"
package_settings = PackageSettings(
    Action.FORCE_REPLACE,
    PackageSettings.UpdateSchema.RECAL_TABLE_LOGICAL_SIZE,
    PackageSettings.AclOnReplacingObjects.REPLACE,
    PackageSettings.AclOnNewObjects.KEEP_ACL_AS_SOURCE_OBJECT,
)

# %% [markdown]
# ## Connect to projects

# %%
source_conn = Connection(base_url=source_base_url,username=source_username,
                  password=source_password,project_id=source_project_id)
#source_conn.headers['Content-type'] = "application/json"

target_conn = Connection(base_url=target_base_url,username=target_username,
                  password=target_password,project_id=target_project_id)

package_name=usr_package_folder_name
mstr_mig_folder=source_conn.environment.storage_service.location 
migration_folder= source_conn.environment.storage_service.location  +"\\"+ usr_migration_folder_name +"\\"+ usr_package_folder_name + "\\"
migration_folder
# Out:
# Connection to MicroStrategy Intelligence Server has been established.
# Connection to MicroStrategy Intelligence Server has been established.
# 'D:\\shared_drive\\MSTR_Migrations\\Daniel_Migration\\20250223_demo\\'

# %% [markdown]
# ## Create package

# %%
package_content_info=bld_mig_list_from_sh_fold(conn=source_conn, folder_id=short_cut_folder_id,action= "FORCE_REPLACE",include_dependents= False)
package_config = PackageConfig(
    package_settings,  package_content_info # [ package_content_from_object]
)

my_obj_mig = Migration.create_object_migration(
    connection=source_conn,
    toc_view=package_config,
    name=package_name,
    project_id=source_conn.project_id,
)

while my_obj_mig.package_info.status == PackageStatus.CREATING:
    sleep(2)
    my_obj_mig.fetch()

my_obj_mig.package_info.status
# Out:
# Folder object named: 'RAG_cubes' with ID: '9316DEEE4820CF81E80157855D37711B'
# Successfully started creation of migration object with ID: '4A051FC5ED84445D8494346E14EC972C:3053753B23F041B380F89D420469ABAC'
# PackageStatus.CREATED

# %%
#my_obj_mig.package_info
package_content_info
# Out:
# []

# %% [markdown]
# ## Validate Package

# %%
# Check migration validation status
my_obj_mig.trigger_validation(
    target_env=target_conn, target_project_name=target_conn.project_name
)

while my_obj_mig.validation.status == ValidationStatus.VALIDATING:
    sleep(2)
    my_obj_mig.fetch()


print(my_obj_mig.validation)
# Out:
# Successfully triggered validation process for migration with ID: '4A051FC5ED84445D8494346E14EC972C:3053753B23F041B380F89D420469ABAC'
# Validation(status=ValidationStatus.VALIDATED, progress=100.0, message='Success', creation_date=datetime.datetime(2025, 3, 17, 7, 34, 16, tzinfo=datetime.timezone.utc), last_update_date=None)

# %% [markdown]
# ## Move Migration Pack to migration folder

# %%
package_file = mstr_mig_folder +"/" +my_obj_mig.package_info.storage.path
package_file=os.path.normpath(package_file)
my_obj_mig_path=shutil.move(package_file, migration_folder)

print("org_file: " +package_file)
print("migration folder: " +my_obj_mig_path)
# Out:
# org_file: D:\shared_drive\MSTR_Migrations\mstr\shared\migrations\packages\2025-03-17\F1EDE4BCBF974828A6BCEB3ACB29ECEC.mmp
# migration folder: D:\shared_drive\MSTR_Migrations\Daniel_Migration\20250223_demo\F1EDE4BCBF974828A6BCEB3ACB29ECEC.mmp

# %% [markdown]
# ## Trigger migration

# %%
from_file_mig = Migration.migrate_from_file(
    connection=target_conn,
    file_path=my_obj_mig_path,
    package_type=PackageType.OBJECT,
    name="object_mig_from_local_storage",
    target_project_name=target_conn.project_name,
)

while from_file_mig.import_info.status == ImportStatus.IMPORTING:
    sleep(2)
    from_file_mig.fetch()

from_file_mig.import_info.status
# Out:
# Successfully started migration from file with ID: '0125EDA0FD24489CABB9A3BE62BAC4AA:3AF5053900B44AD18EC478D956C26C5C'.
# ImportStatus.IMPORTED

# %%
from_file_mig.import_info
# Out:
# ImportInfo(id='1BD8215C8C034EFEB65BC616CC048618', environment={'id': 'http://85.214.60.83:8080/MicroStrategyLibrary/', 'name': 'http://85.214.60.83:8080/MicroStrategyLibrary/'}, creator=User(connection, name='Administrator', id='54F3D26011D2896560009A8E67019608'), creation_date=datetime.datetime(2025, 1, 29, 11, 23, 33, tzinfo=datetime.timezone.utc), last_updated_date=datetime.datetime(2025, 1, 29, 11, 23, 39, tzinfo=datetime.timezone.utc), status=ImportStatus.IMPORTED, import_request_status=RequestStatus.APPROVED, undo_request_status=RequestStatus.PENDING, progress=100.0, message='', undo_storage=PackageStorage(size=10912, path='mstr/shared/migrations/undo/B762307E32934B188F39FC1E6C484DD1/1BD8215C8C034EFEB65BC616CC048618.mmp'), project=Project(connection, name='MicroStrategy Tutorial PreProd', id='00F3103E41FF3743A057C3B5313595B7'), deleted=False)

# %% [markdown]
# ## Archive Migration

# %% [markdown]
# ### move undo mmp file to migration folder

# %%
## move undo mmp to migration folder
undo_source_file = mstr_mig_folder +"/" +from_file_mig.import_info.undo_storage.path
package_file=os.path.normpath(package_file)
new_undo_file=shutil.move(undo_source_file, migration_folder+"Undo.mmp")

print("org_undo_file: " +undo_source_file)
print("migration folder: " +new_undo_file)
# Out:
# org_undo_file: D:\shared_drive\MSTR_Migrations/mstr/shared/migrations/undo/B762307E32934B188F39FC1E6C484DD1/1BD8215C8C034EFEB65BC616CC048618.mmp
# migration folder: D:\shared_drive\MSTR_Migrations\Daniel_Migration\20250223_demo\Undo.mmp

# %% [markdown]
# ### store migrated objects to CSV file

# %%
package_content_df=pd.DataFrame(package_content_info)
package_content_df.to_csv(migration_folder+"package_content.csv")
package_content_df
# Out:
#                                  id  type         action  include_dependents  \
# 0  5D55D4504907E73F560BFBA95AD22A66     3  FORCE_REPLACE               False
# 1  632539C14B768DF229839BA100C92474     4  FORCE_REPLACE               False
# 2  FBA328574EC126D4A38B51AFEF5D7856     4  FORCE_REPLACE               False
# 3  ACB99295488C76AA566DADAE2EC30FC5     4  FORCE_REPLACE               False
#
#    subtype
# 0      768
# 1     1024
# 2     1024
# 3     1024

# %% [markdown]
# ### save package & migration files

# %%
file_path=migration_folder+"package_info.txt"
with open(file_path, "w", encoding="utf-8") as file:
    file.write(str(my_obj_mig.package_info))

file_path=migration_folder+"migration_info.txt"
with open(file_path, "w", encoding="utf-8") as file:
    file.write(str(from_file_mig.import_info))

# %% [markdown]
# ## Read & Store Object definition

# %%
from mstr_robotics.read_out_prj_obj import read_gen
i_read_gen=read_gen()

obj_def_l=[]
for obj in package_content_info:
    obj_def=i_read_gen.get_obj_def(conn=source_conn,object_id=obj["id"],obj_type=obj["type"],obj_sub_type=obj["subtype"])
    obj_def_l.append(obj_def)

file_path=migration_folder+"object_def.json"
with open(file_path, "w", encoding="utf-8") as file:
    file.write(json.dumps(obj_def_l))
    
len(obj_def_l)
# Out:
# 3
# 4
# 4
# 4
# 4

# %%
obj_def_l[0]
# Out:
# {'information': {'dateCreated': '2025-01-22T11:25:14.417Z',
#   'dateModified': '2025-01-22T11:33:19.382Z',
#   'versionId': '00508D754C04B1C3EC0C309FEB41C264',
#   'acg': 255,
#   'primaryLocale': 'en-US',
#   'objectId': '5D55D4504907E73F560BFBA95AD22A66',
#   'subType': 'report_grid',
#   'name': 'Customer Detail report'},
#  'sourceType': 'normal',
#  'dataSource': {'dataTemplate': {'units': [{'id': '56225F324F17B61AEBD88CA256946C96',
#      'name': 'Customer Address',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '8D679D4211D3E4981000E787EC6DE8A4',
#      'name': 'Item',
#      'type': 'attribute',
#      'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5', 'name': 'ID'}],
#      'nonAggregatable': False},
#     {'id': '6E069E4C11D3E4E41000E887EC6DE8A4',
#      'name': 'Customer Age',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '54BABECD11D59D57C000B28A4CC5F24F',
#      'name': 'Brand',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '8D679D3911D3E4981000E787EC6DE8A4',
#      'name': 'Customer Birth Date',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '8D679D3511D3E4981000E787EC6DE8A4',
#      'name': 'Call Center',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '8D679D3F11D3E4981000E787EC6DE8A4',
#      'name': 'Employee',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '8D679D4B11D3E4981000E787EC6DE8A4',
#      'name': 'Region',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '8D679D3A11D3E4981000E787EC6DE8A4',
#      'name': 'Customer City',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '5F0132EE456A636FC8D6E7A59A097AA2',
#      'name': 'Customer Email',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '4151F1304F00A51EB13BCF84283396BE',
#      'name': 'Customer Gender',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '8D679D3711D3E4981000E787EC6DE8A4',
#      'name': 'Category',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '8D679D4F11D3E4981000E787EC6DE8A4',
#      'name': 'Subcategory',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '54BABC8311D59D57C000B28A4CC5F24F',
#      'name': 'Customer State',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '8D679D3C11D3E4981000E787EC6DE8A4',
#      'name': 'Customer',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '96ED3EC811D5B117C000E78A4CC5F24F',
#      'name': 'Day',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '8D679D4411D3E4981000E787EC6DE8A4',
#      'name': 'Month',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '8D679D4511D3E4981000E787EC6DE8A4',
#      'name': 'Month of Year',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '8D679D4A11D3E4981000E787EC6DE8A4',
#      'name': 'Quarter',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'id': '8D679D5111D3E4981000E787EC6DE8A4',
#      'name': 'Year',
#      'type': 'attribute',
#      'nonAggregatable': False},
#     {'type': 'metrics',
#      'elements': [{'id': '632539C14B768DF229839BA100C92474',
#        'name': 'Cost net net',
#        'subType': 'metric'},
#       {'id': '7FD5B69611D5AC76C000D98A4CC5F24F',
#        'name': 'Cost_1',
#        'subType': 'metric'},
#       {'id': '381980B211D40BC8C000C8906B98494F',
#        'name': 'Discount',
#        'subType': 'metric'},
#       {'id': '4C051D4F11D3E877C000B3B2D86C964F',
#        'name': 'Freight',
#        'subType': 'metric'},
#       {'id': '150349F04560BBA2592D019726DF77DD',
#        'name': 'Gross Revenue',
#        'subType': 'metric'},
#       {'id': '4C051DB611D3E877C000B3B2D86C964F',
#        'name': 'Profit',
#        'subType': 'metric'},
#       {'id': '4C05177011D3E877C000B3B2D86C964F',
#        'name': 'Revenue',
#        'subType': 'metric'}],
#      'limit': {'tokens': []}}]},
#   'filter': {'tokens': []}},
#  'grid': {'viewTemplate': {'rows': {'units': [{'id': '56225F324F17B61AEBD88CA256946C96',
#       'name': 'Customer Address',
#       'type': 'attribute'},
#      {'id': '8D679D4211D3E4981000E787EC6DE8A4',
#       'name': 'Item',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5', 'name': 'ID'}]},
#      {'id': '6E069E4C11D3E4E41000E887EC6DE8A4',
#       'name': 'Customer Age',
#       'type': 'attribute'},
#      {'id': '54BABECD11D59D57C000B28A4CC5F24F',
#       'name': 'Brand',
#       'type': 'attribute'},
#      {'id': '8D679D3911D3E4981000E787EC6DE8A4',
#       'name': 'Customer Birth Date',
#       'type': 'attribute'},
#      {'id': '8D679D3511D3E4981000E787EC6DE8A4',
#       'name': 'Call Center',
#       'type': 'attribute'},
#      {'id': '8D679D3F11D3E4981000E787EC6DE8A4',
#       'name': 'Employee',
#       'type': 'attribute'},
#      {'id': '8D679D4B11D3E4981000E787EC6DE8A4',
#       'name': 'Region',
#       'type': 'attribute'},
#      {'id': '8D679D3A11D3E4981000E787EC6DE8A4',
#       'name': 'Customer City',
#       'type': 'attribute'},
#      {'id': '5F0132EE456A636FC8D6E7A59A097AA2',
#       'name': 'Customer Email',
#       'type': 'attribute'},
#      {'id': '4151F1304F00A51EB13BCF84283396BE',
#       'name': 'Customer Gender',
#       'type': 'attribute'},
#      {'id': '8D679D3711D3E4981000E787EC6DE8A4',
#       'name': 'Category',
#       'type': 'attribute'},
#      {'id': '8D679D4F11D3E4981000E787EC6DE8A4',
#       'name': 'Subcategory',
#       'type': 'attribute'},
#      {'id': '54BABC8311D59D57C000B28A4CC5F24F',
#       'name': 'Customer State',
#       'type': 'attribute'},
#      {'id': '8D679D3C11D3E4981000E787EC6DE8A4',
#       'name': 'Customer',
#       'type': 'attribute'},
#      {'id': '96ED3EC811D5B117C000E78A4CC5F24F',
#       'name': 'Day',
#       'type': 'attribute'},
#      {'id': '8D679D4411D3E4981000E787EC6DE8A4',
#       'name': 'Month',
#       'type': 'attribute'},
#      {'id': '8D679D4511D3E4981000E787EC6DE8A4',
#       'name': 'Month of Year',
#       'type': 'attribute'},
#      {'id': '8D679D4A11D3E4981000E787EC6DE8A4',
#       'name': 'Quarter',
#       'type': 'attribute'},
#      {'id': '8D679D5111D3E4981000E787EC6DE8A4',
#       'name': 'Year',
#       'type': 'attribute'}],
#     'sorts': []},
#    'columns': {'units': [{'type': 'metrics',
#       'elements': [{'id': '632539C14B768DF229839BA100C92474',
#         'name': 'Cost net net',
#         'subType': 'metric'},
#        {'id': '7FD5B69611D5AC76C000D98A4CC5F24F',
#         'name': 'Cost_1',
#         'subType': 'metric'},
#        {'id': '381980B211D40BC8C000C8906B98494F',
#         'name': 'Discount',
#         'subType': 'metric'},
#        {'id': '4C051D4F11D3E877C000B3B2D86C964F',
#         'name': 'Freight',
#         'subType': 'metric'},
#        {'id': '150349F04560BBA2592D019726DF77DD',
#         'name': 'Gross Revenue',
#         'subType': 'metric'},
#        {'id': '4C051DB611D3E877C000B3B2D86C964F',
#         'name': 'Profit',
#         'subType': 'metric'},
#        {'id': '4C05177011D3E877C000B3B2D86C964F',
#         'name': 'Revenue',
#         'subType': 'metric'}]}],
#     'sorts': []},
#    'pageBy': {}},
#   'viewFilter': {}},
#  'advancedProperties': {'vldbProperties': {'[VLDB Select].[Allow Cartesian Join]': {'name': 'Allow Cartesian Join',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Base Table Join for Template]': {'name': 'Base Table Join for Template',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Cross Join Order]': {'name': 'Cross Join Order',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Downward Outer Join]': {'name': 'Downward Outer Join',
#     'type': 'int32',
#     'value': '2',
#     'resolvedLocation': 'db_role',
#     'isInherited': True},
#    '[VLDB Select].[DSS Star Join]': {'name': 'DSS Star Join',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Fact Table Switch]': {'name': 'Fact Table Switch',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Full Outer Join Support]': {'name': 'Full Outer Join Support',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'dbms',
#     'isInherited': True},
#    '[VLDB Select].[Incomplete Lookup Table]': {'name': 'Incomplete Lookup Table',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Join Attribute Option]': {'name': 'Join Attribute Option',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Join Type]': {'name': 'Join Type',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Lookup Table Join Order]': {'name': 'Lookup Table Join Order',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Max Tables in Join Warning]': {'name': 'Max Tables in Join Warning',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Nested Aggregation Outer Join]': {'name': 'Nested Aggregation Outer Join',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Outer Join To Lookup Table]': {'name': 'Outer Join To Lookup Table',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Function].[Null Check]': {'name': 'Null Check',
#     'type': 'int32',
#     'value': '2',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Function].[Zero Check]': {'name': 'Zero Check',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Absolute Non-Agg Metric Query Type]': {'name': 'Absolute Non-Agg Metric Query Type',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Compute Non-Agg After Analytics]': {'name': 'Compute Non-Agg After Analytics',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Non-Agg Metric Optimization]': {'name': 'Non-Agg Metric Optimization',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Use Subtotal Dimty for Dynamic Aggregation]': {'name': 'Use Subtotal Dimty for Dynamic Aggregation',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table PostStatement 1]': {'name': 'Table PostStatement 1',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table PostStatement 2]': {'name': 'Table PostStatement 2',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table PostStatement 3]': {'name': 'Table PostStatement 3',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table PostStatement 4]': {'name': 'Table PostStatement 4',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table PostStatement 5]': {'name': 'Table PostStatement 5',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table PreStatement 1]': {'name': 'Table PreStatement 1',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table PreStatement 2]': {'name': 'Table PreStatement 2',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table PreStatement 3]': {'name': 'Table PreStatement 3',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table PreStatement 4]': {'name': 'Table PreStatement 4',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table PreStatement 5]': {'name': 'Table PreStatement 5',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Drop].[Post Cleanup Statement 1]': {'name': 'Post Cleanup Statement 1',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Drop].[Post Cleanup Statement 2]': {'name': 'Post Cleanup Statement 2',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Drop].[Post Cleanup Statement 3]': {'name': 'Post Cleanup Statement 3',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Drop].[Post Cleanup Statement 4]': {'name': 'Post Cleanup Statement 4',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Drop].[Post Cleanup Statement 5]': {'name': 'Post Cleanup Statement 5',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert MidStatement 1]': {'name': 'Insert MidStatement 1',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert MidStatement 2]': {'name': 'Insert MidStatement 2',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert MidStatement 3]': {'name': 'Insert MidStatement 3',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert MidStatement 4]': {'name': 'Insert MidStatement 4',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert MidStatement 5]': {'name': 'Insert MidStatement 5',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert PostStatement 1]': {'name': 'Insert PostStatement 1',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert PostStatement 2]': {'name': 'Insert PostStatement 2',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert PostStatement 3]': {'name': 'Insert PostStatement 3',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert PostStatement 4]': {'name': 'Insert PostStatement 4',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert PostStatement 5]': {'name': 'Insert PostStatement 5',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert PreStatement 1]': {'name': 'Insert PreStatement 1',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert PreStatement 2]': {'name': 'Insert PreStatement 2',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert PreStatement 3]': {'name': 'Insert PreStatement 3',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert PreStatement 4]': {'name': 'Insert PreStatement 4',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert PreStatement 5]': {'name': 'Insert PreStatement 5',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Drop Database Connection]': {'name': 'Drop Database Connection',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Report PostStatement 1]': {'name': 'Report PostStatement 1',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Report PostStatement 2]': {'name': 'Report PostStatement 2',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Report PostStatement 3]': {'name': 'Report PostStatement 3',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Report PostStatement 4]': {'name': 'Report PostStatement 4',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Report PostStatement 5]': {'name': 'Report PostStatement 5',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Report PreStatement 1]': {'name': 'Report PreStatement 1',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Report PreStatement 2]': {'name': 'Report PreStatement 2',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Report PreStatement 3]': {'name': 'Report PreStatement 3',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Report PreStatement 4]': {'name': 'Report PreStatement 4',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Report PreStatement 5]': {'name': 'Report PreStatement 5',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Session Based PostStatement]': {'name': 'Session Based PostStatement',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Session Based PreStatement]': {'name': 'Session Based PreStatement',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Function].[Custom Group Banding Count Method]': {'name': 'Custom Group Banding Count Method',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Function].[Custom Group Banding Points Method]': {'name': 'Custom Group Banding Points Method',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Function].[Custom Group Banding Size Method]': {'name': 'Custom Group Banding Size Method',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Function].[Rank Method]': {'name': 'Rank Method',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Count Distinct with Partitions]': {'name': 'Count Distinct with Partitions',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Filter on selection behavior for standard and OLAP Reports]': {'name': 'Filter on selection behavior for standard and OLAP Reports',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Incremental Data Transfer]': {'name': 'Incremental Data Transfer',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Additional Final Pass]': {'name': 'Additional Final Pass',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Apply Filter to All Passes]': {'name': 'Apply Filter to All Passes',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Dimensionality Model]': {'name': 'Dimensionality Model',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Filter tree optimization for metric qualifications]': {'name': 'Filter tree optimization for metric qualifications',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Keep Unrelated Filter]': {'name': 'Keep Unrelated Filter',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[MD Partition Prequery Option]': {'name': 'MD Partition Prequery Option',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Non-Groupby]': {'name': 'Non-Groupby',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Normalization For Normal Report]': {'name': 'Normalization For Normal Report',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[OLAP New Behavior]': {'name': 'OLAP New Behavior',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Parallel SQL Execution]': {'name': 'Parallel SQL Execution',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Parameterized Query for Text Input]': {'name': 'Parameterized Query for Text Input',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'dbms',
#     'isInherited': True},
#    '[VLDB Select].[PSE Improvement in SQLView]': {'name': 'PSE Improvement in SQLView',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Remove Aggregation method]': {'name': 'Remove Aggregation method',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Remove Repeated Tables For Outer Joins]': {'name': 'Remove Repeated Tables For Outer Joins',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Remove Unreferenced and Duplicates]': {'name': 'Remove Unreferenced and Duplicates',
#     'type': 'int32',
#     'value': '4',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Set Operation]': {'name': 'Set Operation',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'dbms',
#     'isInherited': True},
#    '[VLDB Select].[Sub Query Type]': {'name': 'Sub Query Type',
#     'type': 'int32',
#     'value': '3',
#     'resolvedLocation': 'dbms',
#     'isInherited': True},
#    '[VLDB Select].[Transformation Optimization]': {'name': 'Transformation Optimization',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Unrelated Filter Options For Nested Metrics]': {'name': 'Unrelated Filter Options For Nested Metrics',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[WHERE Clause Driving Table]': {'name': 'WHERE Clause Driving Table',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Commit Level]': {'name': 'Commit Level',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Create PostString]': {'name': 'Create PostString',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Fallback Table Type]': {'name': 'Fallback Table Type',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'dbms',
#     'isInherited': True},
#    '[VLDB Create].[Intermediate Table Type]': {'name': 'Intermediate Table Type',
#     'type': 'int32',
#     'value': '3',
#     'resolvedLocation': 'dbms',
#     'isInherited': True},
#    '[VLDB Create].[Table Creation Type]': {'name': 'Table Creation Type',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table Descriptor]': {'name': 'Table Descriptor',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table Option]': {'name': 'Table Option',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table Prefix]': {'name': 'Table Prefix',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table Qualifier]': {'name': 'Table Qualifier',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Table Space]': {'name': 'Table Space',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Drop].[Commit After Final Drop]': {'name': 'Commit After Final Drop',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Drop].[Drop Temp Table Method]': {'name': 'Drop Temp Table Method',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Table Type Fallback Max Pass]': {'name': 'Table Type Fallback Max Pass',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Table Type Fallback Max Table]': {'name': 'Table Type Fallback Max Table',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Allow Index On Fact]': {'name': 'Allow Index On Fact',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Create Individual Index]': {'name': 'Create Individual Index',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Index PostString]': {'name': 'Index PostString',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Index Prefix]': {'name': 'Index Prefix',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Index Qualifier]': {'name': 'Index Qualifier',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Intermediate Table Index]': {'name': 'Intermediate Table Index',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Max Columns in Index]': {'name': 'Max Columns in Index',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Primary Index Control]': {'name': 'Primary Index Control',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Create].[Secondary Index Order]': {'name': 'Secondary Index Order',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Syntax].[Max Columns in Wildcard]': {'name': 'Max Columns in Wildcard',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Data Type].[Date Format]': {'name': 'Date Format',
#     'type': 'string',
#     'value': 'yyyy-mm-dd',
#     'resolvedLocation': 'dbms',
#     'isInherited': True},
#    '[VLDB Data Type].[Date Pattern]': {'name': 'Date Pattern',
#     'type': 'string',
#     'value': "to_date('#0'::text,'YYYY-MM-DD')",
#     'resolvedLocation': 'dbms',
#     'isInherited': True},
#    '[VLDB Data Type].[Time Format]': {'name': 'Time Format',
#     'type': 'string',
#     'value': 'hh:nn:ss',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Data Type].[TimeStamp Format]': {'name': 'TimeStamp Format',
#     'type': 'string',
#     'value': 'yyyy-mm-dd hh:nn:ss',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Data Type].[Use BigInt For Long Integer]': {'name': 'Use BigInt For Long Integer',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Bulk Insert String]': {'name': 'Bulk Insert String',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Constant Column Mode]': {'name': 'Constant Column Mode',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Insert Table Option]': {'name': 'Insert Table Option',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[Post Insert String]': {'name': 'Post Insert String',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Insert].[UNION Multiple INSERTs]': {'name': 'UNION Multiple INSERTs',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Attribute Form Select for Intermediate Pass]': {'name': 'Attribute Form Select for Intermediate Pass',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Attribute Selection Option for Intermediate Pass]': {'name': 'Attribute Selection Option for Intermediate Pass',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Data Retrieval Mode]': {'name': 'Data Retrieval Mode',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Data Retrieval Parameters]': {'name': 'Data Retrieval Parameters',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Datamart Column Order]': {'name': 'Datamart Column Order',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Decimal Separator]': {'name': 'Decimal Separator',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Disable Prefix in WH Partition Table]': {'name': 'Disable Prefix in WH Partition Table',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Do Not Merge Same Metric Expression]': {'name': 'Do Not Merge Same Metric Expression',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[GROUP BY ID Attribute]': {'name': 'GROUP BY ID Attribute',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[GROUP BY Non-ID Attribute]': {'name': 'GROUP BY Non-ID Attribute',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Parameterized SQL View]': {'name': 'Parameterized SQL View',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[SELECT DISTINCT at Same Level]': {'name': 'SELECT DISTINCT at Same Level',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[SELECT PostString]': {'name': 'SELECT PostString',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[SELECT PostString For Main SQL]': {'name': 'SELECT PostString For Main SQL',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[SQL Hint]': {'name': 'SQL Hint',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Autocommit]': {'name': 'Autocommit',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Report].[Report Time Out]': {'name': 'Report Time Out',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Intermediate Row Limit]': {'name': 'Intermediate Row Limit',
#     'type': 'int32',
#     'value': '-1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Results Set Row Limit]': {'name': 'Results Set Row Limit',
#     'type': 'int32',
#     'value': '-1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[AnalyticalEngineProperties].[ConsolidationSubtotal]': {'name': 'ConsolidationSubtotal',
#     'type': 'boolean',
#     'value': 'true',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[AnalyticalEngineProperties].[EvaluationOrdering]': {'name': 'EvaluationOrdering',
#     'type': 'int32',
#     'value': '2',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[AnalyticalEngineProperties].[MetricLevelDetermination]': {'name': 'MetricLevelDetermination',
#     'type': 'boolean',
#     'value': 'false',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[AnalyticalEngineProperties].[NullCheckingForAnalyticalEngine]': {'name': 'NullCheckingForAnalyticalEngine',
#     'type': 'int32',
#     'value': '2',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[AnalyticalEngineProperties].[SubtotalDimensionalityAware]': {'name': 'SubtotalDimensionalityAware',
#     'type': 'boolean',
#     'value': 'true',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Apply Filter Options for queries against in-memory datasets]': {'name': 'Apply Filter Options for queries against in-memory datasets',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[MDX Syntax].[MDX Add Fake Measure]': {'name': 'MDX Add Fake Measure',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[MDX Syntax].[MDX Add Generation Property]': {'name': 'MDX Add Generation Property',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[MDX Syntax].[MDX Add Non Empty]': {'name': 'MDX Add Non Empty',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[MDX Syntax].[MDX Cell Formatting]': {'name': 'MDX Cell Formatting',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[MDX Syntax].[MDX Has Measure Values Include Other Hierarchies]': {'name': 'MDX Has Measure Values Include Other Hierarchies',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[MDX Syntax].[MDX Measure Dimension Name]': {'name': 'MDX Measure Dimension Name',
#     'type': 'string',
#     'value': '[Measures]',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[MDX Syntax].[MDX Measure Values to Treat as Null]': {'name': 'MDX Measure Values to Treat as Null',
#     'type': 'string',
#     'value': 'X',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[MDX Syntax].[MDX Non Empty Optimization]': {'name': 'MDX Non Empty Optimization',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[MDX Syntax].[MDX Property Key Date Format]': {'name': 'MDX Property Key Date Format',
#     'type': 'string',
#     'value': 'DD.MM.YYYY',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[MDX Syntax].[MDX TopCount Support]': {'name': 'MDX TopCount Support',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[MDX Syntax].[MDX Treat Key Date Qualification As ID Date Qualification]': {'name': 'MDX Treat Key Date Qualification As ID Date Qualification',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[MDX Syntax].[MDX Verify Limit Filter Literal Level]': {'name': 'MDX Verify Limit Filter Literal Level',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Aggregation Tables Problems]': {'name': 'Aggregation Tables Problems',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Cube Reuse for Ad Hoc For Current Report Enabled]': {'name': 'Cube Reuse for Ad Hoc For Current Report Enabled',
#     'type': 'int32',
#     'value': '1',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Extended Mismatch Log Enabled in SQL View for Dynamic Sourcing]': {'name': 'Extended Mismatch Log Enabled in SQL View for Dynamic Sourcing',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Mismatch Log Enabled in SQL View for Dynamic Sourcing]': {'name': 'Mismatch Log Enabled in SQL View for Dynamic Sourcing',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Select].[Report Parse Log Enabled in SQL View for Dynamic Sourcing]': {'name': 'Report Parse Log Enabled in SQL View for Dynamic Sourcing',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[GeneralReportProperties].[AllowMobileTemporaryCaching]': {'name': 'AllowMobileTemporaryCaching',
#     'type': 'boolean',
#     'value': 'true',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[GeneralReportProperties].[EnableReportCaching]': {'name': 'EnableReportCaching',
#     'type': 'int32',
#     'value': '2',
#     'resolvedLocation': 'project',
#     'isInherited': True},
#    '[VLDB Select].[Multisource database instance selection option]': {'name': 'Multisource database instance selection option',
#     'type': 'int32',
#     'value': '0',
#     'resolvedLocation': 'project',
#     'isInherited': True},
#    '[AnalyticalEngineProperties].[DisplayNullOnTop]': {'name': 'DisplayNullOnTop',
#     'type': 'boolean',
#     'value': 'false',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[AnalyticalEngineProperties].[DisplayNullReplace]': {'name': 'DisplayNullReplace',
#     'type': 'boolean',
#     'value': 'false',
#     'resolvedLocation': 'project',
#     'isInherited': True},
#    '[AnalyticalEngineProperties].[DisplayNullReplaceValue]': {'name': 'DisplayNullReplaceValue',
#     'type': 'double',
#     'value': '0.0',
#     'resolvedLocation': 'project',
#     'isInherited': True},
#    '[AnalyticalEngineProperties].[HideNullZeroValues]': {'name': 'HideNullZeroValues',
#     'type': 'int32',
#     'value': '2',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[AnalyticalEngineProperties].[NotCalculatedDisplay]': {'name': 'NotCalculatedDisplay',
#     'type': 'string',
#     'value': '--',
#     'resolvedLocation': 'project',
#     'isInherited': True},
#    '[AnalyticalEngineProperties].[ShowAllRows]': {'name': 'ShowAllRows',
#     'type': 'boolean',
#     'value': 'true',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Function].[Missing Display]': {'name': 'Missing Display',
#     'type': 'string',
#     'value': '',
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    '[VLDB Function].[Null Display]': {'name': 'Null Display',
#     'type': 'string',
#     'value': ',',
#     'resolvedLocation': 'project',
#     'isInherited': True}},
#   'metricJoinTypes': {'632539C14B768DF229839BA100C92474': {'metric': {'objectId': '632539C14B768DF229839BA100C92474',
#      'subType': 'metric',
#      'name': 'Cost net net'},
#     'joinType': 'outer',
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextJoinType': 'outer',
#     'nextResolvedLocation': 'template_target'},
#    '7FD5B69611D5AC76C000D98A4CC5F24F': {'metric': {'objectId': '7FD5B69611D5AC76C000D98A4CC5F24F',
#      'subType': 'metric',
#      'name': 'Cost_1'},
#     'joinType': 'inner',
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextJoinType': 'inner',
#     'nextResolvedLocation': 'default'},
#    '381980B211D40BC8C000C8906B98494F': {'metric': {'objectId': '381980B211D40BC8C000C8906B98494F',
#      'subType': 'metric',
#      'name': 'Discount'},
#     'joinType': 'inner',
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextJoinType': 'inner',
#     'nextResolvedLocation': 'default'},
#    '4C051D4F11D3E877C000B3B2D86C964F': {'metric': {'objectId': '4C051D4F11D3E877C000B3B2D86C964F',
#      'subType': 'metric',
#      'name': 'Freight'},
#     'joinType': 'inner',
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextJoinType': 'inner',
#     'nextResolvedLocation': 'default'},
#    '150349F04560BBA2592D019726DF77DD': {'metric': {'objectId': '150349F04560BBA2592D019726DF77DD',
#      'subType': 'metric',
#      'name': 'Gross Revenue'},
#     'joinType': 'inner',
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextJoinType': 'inner',
#     'nextResolvedLocation': 'default'},
#    '4C051DB611D3E877C000B3B2D86C964F': {'metric': {'objectId': '4C051DB611D3E877C000B3B2D86C964F',
#      'subType': 'metric',
#      'name': 'Profit'},
#     'joinType': 'inner',
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextJoinType': 'inner',
#     'nextResolvedLocation': 'default'},
#    '4C05177011D3E877C000B3B2D86C964F': {'metric': {'objectId': '4C05177011D3E877C000B3B2D86C964F',
#      'subType': 'metric',
#      'name': 'Revenue'},
#     'joinType': 'inner',
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextJoinType': 'inner',
#     'nextResolvedLocation': 'default'}},
#   'attributeJoinTypes': {'56225F324F17B61AEBD88CA256946C96': {'attribute': {'objectId': '56225F324F17B61AEBD88CA256946C96',
#      'subType': 'attribute',
#      'name': 'Customer Address'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '8D679D4211D3E4981000E787EC6DE8A4': {'attribute': {'objectId': '8D679D4211D3E4981000E787EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Item'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '6E069E4C11D3E4E41000E887EC6DE8A4': {'attribute': {'objectId': '6E069E4C11D3E4E41000E887EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Customer Age'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '54BABECD11D59D57C000B28A4CC5F24F': {'attribute': {'objectId': '54BABECD11D59D57C000B28A4CC5F24F',
#      'subType': 'attribute',
#      'name': 'Brand'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '8D679D3911D3E4981000E787EC6DE8A4': {'attribute': {'objectId': '8D679D3911D3E4981000E787EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Customer Birth Date'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '8D679D3511D3E4981000E787EC6DE8A4': {'attribute': {'objectId': '8D679D3511D3E4981000E787EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Call Center'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '8D679D3F11D3E4981000E787EC6DE8A4': {'attribute': {'objectId': '8D679D3F11D3E4981000E787EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Employee'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '8D679D4B11D3E4981000E787EC6DE8A4': {'attribute': {'objectId': '8D679D4B11D3E4981000E787EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Region'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '8D679D3A11D3E4981000E787EC6DE8A4': {'attribute': {'objectId': '8D679D3A11D3E4981000E787EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Customer City'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '5F0132EE456A636FC8D6E7A59A097AA2': {'attribute': {'objectId': '5F0132EE456A636FC8D6E7A59A097AA2',
#      'subType': 'attribute',
#      'name': 'Customer Email'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '4151F1304F00A51EB13BCF84283396BE': {'attribute': {'objectId': '4151F1304F00A51EB13BCF84283396BE',
#      'subType': 'attribute',
#      'name': 'Customer Gender'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '8D679D3711D3E4981000E787EC6DE8A4': {'attribute': {'objectId': '8D679D3711D3E4981000E787EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Category'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '8D679D4F11D3E4981000E787EC6DE8A4': {'attribute': {'objectId': '8D679D4F11D3E4981000E787EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Subcategory'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '54BABC8311D59D57C000B28A4CC5F24F': {'attribute': {'objectId': '54BABC8311D59D57C000B28A4CC5F24F',
#      'subType': 'attribute',
#      'name': 'Customer State'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '8D679D3C11D3E4981000E787EC6DE8A4': {'attribute': {'objectId': '8D679D3C11D3E4981000E787EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Customer'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '96ED3EC811D5B117C000E78A4CC5F24F': {'attribute': {'objectId': '96ED3EC811D5B117C000E78A4CC5F24F',
#      'subType': 'attribute',
#      'name': 'Day'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '8D679D4411D3E4981000E787EC6DE8A4': {'attribute': {'objectId': '8D679D4411D3E4981000E787EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Month'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '8D679D4511D3E4981000E787EC6DE8A4': {'attribute': {'objectId': '8D679D4511D3E4981000E787EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Month of Year'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '8D679D4A11D3E4981000E787EC6DE8A4': {'attribute': {'objectId': '8D679D4A11D3E4981000E787EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Quarter'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'},
#    '8D679D5111D3E4981000E787EC6DE8A4': {'attribute': {'objectId': '8D679D5111D3E4981000E787EC6DE8A4',
#      'subType': 'attribute',
#      'name': 'Year'},
#     'noParticipationInPreserveRow': False,
#     'resolvedLocation': 'report_target',
#     'isInherited': False,
#     'nextNoParticipationInPreserveRow': False,
#     'nextResolvedLocation': 'default'}},
#   'drillOptions': {'drillingEnableReportDrilling': {'value': True,
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    'drillingOptions': {'value': 1,
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    'drillingKeepParentEx': {'value': -1,
#     'resolvedLocation': 'template',
#     'isInherited': False},
#    'drillingThresholds': {'value': -1,
#     'resolvedLocation': 'template',
#     'isInherited': False},
#    'drillingInheritSubtotalsFromParent': {'value': -1,
#     'resolvedLocation': 'template',
#     'isInherited': False},
#    'drillingPageByToFilter': {'value': True,
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    'drillingPageByAllElements': {'value': 0,
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    'drillingPageByToFilterBody': {'value': False,
#     'resolvedLocation': 'default',
#     'isInherited': True},
#    'drillingFilterOption': {'value': 0,
#     'resolvedLocation': 'default',
#     'isInherited': True}},
#   'useDefaultEvaluationOrder': True,
#   'promptOrdering': []}}

# %%
source_conn.close()
target_conn.close()
# Out:
# Connection to MicroStrategy Intelligence Server has been closed.
# Connection to MicroStrategy Intelligence Server has been closed.

# %% [markdown]
# ## Run undo

# %%
from_file_mig = Migration.migrate_from_file(
    connection=target_conn,
    file_path=new_undo_file,
    package_type=PackageType.OBJECT,
    name="object_mig_from_local_storage",
    target_project_name=target_conn.project_name,
)

while from_file_mig.import_info.status == ImportStatus.IMPORTING:
    sleep(2)
    from_file_mig.fetch()

from_file_mig.import_info.status
