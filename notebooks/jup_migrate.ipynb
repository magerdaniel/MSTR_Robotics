# %% [markdown]
# ## Strateg(P)ython Migration

# %% [markdown]
# ### Load libraries

# %%
import json
import time

import yaml
import os
import tempfile
import pandas as pd
from time import sleep
from mstr_robotics._paths import CONFIG_DIR, USER_CONFIG
from mstr_robotics.mstr_classes import get_conn
from mstr_robotics.read_out_prj_obj import ReadGen
from mstr_robotics.ms_azure import MsAzure
from mstr_robotics.select_mig_objects import BldMigContent

from azure.storage.blob import BlobServiceClient

from mstrio.object_management.migration import (
    PackageType,
    Migration,
    PackageConfig,
    PackageSettings
)

from mstrio.object_management.migration.package import (
    Action,
    ImportStatus,
    PackageStatus,
    ValidationStatus,
)


i_read_gen=ReadGen()
i_ms_azure=MsAzure()
i_bld_mig_content=BldMigContent()

try:
    with open(USER_CONFIG, 'r') as openfile:
        user_d = yaml.safe_load(openfile)
        conn_params =  user_d["conn_params"]
except Exception as err:
    print(err)

try:
    with open(CONFIG_DIR / "dans_migrations.yml", "r", encoding="utf-8") as f:
        config = yaml.safe_load(f)
except Exception as err:
    print(err)

# %% [markdown]
# ### Config

# %%
usr_migration_folder_name="Daniel_Migration"
usr_package_folder_name="objects"

migrations_excel_file="C:\\Users\\danie\\Downloads\\mig_list.xlsx"
migrations_excel_df=pd.read_excel(migrations_excel_file)

# %%
# Configure Azure
container_name = config['azure_storage']['container_name']
account_name = config['azure_storage']['account_name']
AccountKey = config['azure_storage']['account_key']
short_cut_folder_id = config['microstrategy']['short_cut_folder_id']
source_project_id = config['microstrategy']['source_project_id']
target_project_id = config['microstrategy']['target_project_id']
directory_path = config['directory']['path']

connection_string = f"DefaultEndpointsProtocol=https;AccountName={account_name};AccountKey={AccountKey};EndpointSuffix=core.windows.net"

# %%
#Configure migration
package_settings = PackageSettings(
    Action.FORCE_REPLACE,
    PackageSettings.UpdateSchema.RECAL_TABLE_LOGICAL_SIZE,
    PackageSettings.AclOnReplacingObjects.REPLACE,
    PackageSettings.AclOnNewObjects.KEEP_ACL_AS_SOURCE_OBJECT,
)

# %% [markdown]
# ### Connect to projects

# %%
conn_params["project_id"]=source_project_id
source_conn = get_conn(**conn_params)
conn_params["project_id"]=target_project_id
target_conn = get_conn(**conn_params)

target_conn.headers.pop("Content-Type", None)
source_conn.headers.pop("Content-Type", None)

blob_service_client = BlobServiceClient.from_connection_string(connection_string)
# Out:
# Connection to Strategy Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'MicroStrategy Tutorial' with ID: 'B7CA92F04B9FAE8D941C3E9B7E0CD754'
# Connection to Strategy Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'MicroStrategy Tutorial AI Test' with ID: '5900929C4EEA246D22FDCAAED117E17D'

# %% [markdown]
# ### Create package

# %%
package_content_info=i_bld_mig_content.from_excel(conn=source_conn, excel_df=migrations_excel_df,action= "FORCE_REPLACE",include_dependents= False)
package_config = PackageConfig(
    package_settings,  package_content_info # [ package_content_from_object]
)

my_obj_mig = Migration.create_object_migration(
    connection=source_conn,
    toc_view=package_config,
    name=usr_package_folder_name,
    project_id=source_conn.project_id,
)

while my_obj_mig.package_info.status == PackageStatus.CREATING:
    sleep(2)
    my_obj_mig.fetch()

my_obj_mig.package_info.status
# Out:
# Object with GUID BB1630284A9D1EA06DCF69A1A57BD24B not found.
# Object with GUID 9BB06A4C43974CEF178D2D9843018297 not found.
# Object with GUID E098E8DD49B73D9FBE4F17ACC6774F3E not found.
# Object with GUID 2F2302AE4D1C2DDDFA9CDCB46802B185 not found.
# Object with GUID 96648F2B492150A6AA27DDB3744E32B4 not found.
# Successfully started creation of migration object with ID: '4369A91B66C145099ECE85BFF5529555:F0A6BCFE4E644082AA757BFAFB27FFD1'
# PackageStatus.CREATED

# %% [markdown]
# ### Validate Package

# %%
# Check migration validation status
my_obj_mig.trigger_validation(
    target_env=target_conn, target_project_name=target_conn.project_name
)

while my_obj_mig.validation.status == ValidationStatus.VALIDATING:
    sleep(2)
    my_obj_mig.fetch()

print(my_obj_mig.validation)
# Out:
# Project object named: 'MicroStrategy Tutorial AI Test' with ID: '5900929C4EEA246D22FDCAAED117E17D'
# Successfully triggered validation process for migration with ID: '4369A91B66C145099ECE85BFF5529555:F0A6BCFE4E644082AA757BFAFB27FFD1'
# Validation(status=ValidationStatus.VALIDATED, progress=100.0, message='Success', creation_date=datetime.datetime(2026, 7, 28, 4, 29, 32, tzinfo=datetime.timezone.utc), last_update_date=None)

# %% [markdown]
# ### Move Migration Pack to migration folder

# %%
source_path=my_obj_mig.package_info.storage.path
file_name = os.path.basename(source_path)
parent_dir = os.path.dirname(source_path)

# Build target path in the same parent directory
target_path = f"{parent_dir}/{usr_package_folder_name}/{file_name}"
target_folder_name=usr_package_folder_name

i_ms_azure.move_blob_to_folder(connection_string, container_name
                    , source_path, target_path)
# Out:
# {'success': True,
#  'source_path': 'mstr/shared/migrations/packages/2026-07-28/387D4550D87A4E29A710404ED76A6EB5.mmp',
#  'target_path': 'mstr/shared/migrations/packages/2026-07-28/tutorial_objects/387D4550D87A4E29A710404ED76A6EB5.mmp',
#  'operation': 'moved',
#  'copy_operation': {'etag': '"0x8DEEC60D6BE957C"',
#   'last_modified': datetime.datetime(2026, 7, 28, 4, 29, 39, tzinfo=datetime.timezone.utc),
#   'client_request_id': 'e51ae842-8a3c-11f1-a44f-52c2e8bae35d',
#   'request_id': '8797bf17-401e-0039-5949-1e36fd000000',
#   'version': '2026-06-06',
#   'version_id': None,
#   'date': datetime.datetime(2026, 7, 28, 4, 29, 39, tzinfo=datetime.timezone.utc),
#   'copy_id': '2fe0d8d4-f89f-46dd-99e0-55973aa33a97',
#   'copy_status': 'success'}}

# %% [markdown]
# ### Trigger migration

# %%
blob_client = blob_service_client.get_blob_client(
# Get blob client
    container=container_name,
    blob=target_path
)

# Download to temporary file
with tempfile.NamedTemporaryFile(delete=False, suffix='.mmp') as tmp_file:
    download_stream = blob_client.download_blob()
    tmp_file.write(download_stream.readall())
    temp_file_path = tmp_file.name

# Now use the temporary file with migrate_from_file

from_file_mig = Migration.migrate_from_file(
    connection=target_conn,
    file_path=temp_file_path,
    package_type=PackageType.OBJECT,
    name="object_mig_from_azure_storage",
    target_project_name=target_conn.project_name
)
while from_file_mig.import_info.status == ImportStatus.IMPORTING:
    sleep(2)
    from_file_mig.fetch()

from_file_mig.import_info.status
# Out:
# Project object named: 'MicroStrategy Tutorial AI Test' with ID: '5900929C4EEA246D22FDCAAED117E17D'
# Successfully started migration from file with ID: 'AC470B4AB368412CACBCC948D75B56D9:4A18CC9E0F754FF3AC89A384B996CA9E'.
# ImportStatus.IMPORTED

# %%
mstr_migration_dir = os.path.dirname(my_obj_mig.package_info.storage.path)
mstr_migration_dir
# Out:
# 'mstr/shared/migrations/packages/2026-07-28'

# %% [markdown]
# ## Archive Migration

# %% [markdown]
# ### move undo mmp file to migration folder

# %%
source_path= from_file_mig.import_info.undo_storage.path
file_name = os.path.basename(source_path)
target_path = f"{parent_dir}/{usr_package_folder_name}/undo.mmp"
i_ms_azure.move_blob_to_folder(connection_string, container_name, source_path, target_path)
# Out:
# {'success': True,
#  'source_path': 'mstr/shared/migrations/undo/AC470B4AB368412CACBCC948D75B56D9/4A18CC9E0F754FF3AC89A384B996CA9E.mmp',
#  'target_path': 'mstr/shared/migrations/packages/2026-07-28/tutorial_objects/undo.mmp',
#  'operation': 'moved',
#  'copy_operation': {'etag': '"0x8DEEC60E1FC355D"',
#   'last_modified': datetime.datetime(2026, 7, 28, 4, 29, 58, tzinfo=datetime.timezone.utc),
#   'client_request_id': 'f05cdd33-8a3c-11f1-9e01-52c2e8bae35d',
#   'request_id': '6419d8da-a01e-000e-5549-1ee451000000',
#   'version': '2026-06-06',
#   'version_id': None,
#   'date': datetime.datetime(2026, 7, 28, 4, 29, 57, tzinfo=datetime.timezone.utc),
#   'copy_id': '6985b41c-ca1c-4b71-9b1a-c2e633b08b04',
#   'copy_status': 'success'}}

# %% [markdown]
# ### store migrated objects to CSV file

# %%
# Store migrated objects to CSV file at target path
package_content_df = pd.DataFrame(package_content_info)

# Build target path for CSV
csv_target_path = f"{parent_dir}/{target_folder_name}/package_content.csv"

# Create blob client for CSV
csv_blob_client = blob_service_client.get_blob_client(
    container=container_name,
    blob=csv_target_path
)

# Convert DataFrame to CSV string
csv_data = package_content_df.to_csv(index=False)

# Upload CSV to Azure Blob Storage
csv_blob_client.upload_blob(csv_data, overwrite=True)

print(f"CSV saved to: {csv_target_path}")
package_content_df
# Out:
# CSV saved to: mstr/shared/migrations/packages/2026-07-28/tutorial_objects/package_content.csv
#                                   id  type         action  include_dependents  \
# 0   A8B8EF0949433604826137AC569859E3     3  force_replace               False
# 1   9981CB214C79D75EC342A781539A4E5A     8  force_replace               False
# 2   293664374424ADAC7D3615AE3B384907     3  force_replace               False
# 3   032A5E114A59D28267BDD8B6D9E58B22     8  force_replace               False
# 4   CF2049E94A0000A16532D39C6D783F1D     8  force_replace               False
# 5   7F16A4B811E58ED317D50080EFF554EA     8  force_replace               False
# 6   7065AA4C48A2044AF0BEED95042A4870     3  force_replace               False
# 7   14B57F1F46127BC6E6F746888BC3C7CB    10  force_replace               False
# 8   1F21042E4FC08886A9D7E4920CA4EC59    10  force_replace               False
# 9   21BCCD6C4110696EABE622B71D1C0566     3  force_replace               False
# 10  25D40AD444B6D51B333021ADFB219501     3  force_replace               False
# 11  2AF7E8744FE8F3FEA97110AC3A3AA5EF    10  force_replace               False
# 12  2B028FBC466C3DC839E1E092FDF4CC56     8  force_replace               False
# 13  3673EC9146EE4DF3517725BBA97A4B36     3  force_replace               False
# 14  3E312E64489040609C0A63800A4E3BAE     3  force_replace               False
# 15  410F74B843A27E1BB7BF9C8891EA8D0C     1  force_replace               False
# 16  5D8A265D4A08641AAB76DAB74440A41C     3  force_replace               False
# 17  6BB3C88A44CF937F0770B4BE22E86118    10  force_replace               False
# 18  745D4D304697491769F4F4B41E906BE0     3  force_replace               False
# 19  986E6D1A427030A710A0E68F74290482     8  force_replace               False
# 20  AC7CC55242A3512A1709BD8EB9A7A73A     8  force_replace               False
# 21  AFA89D9C4313375DC9945AA4634C5FED     3  force_replace               False
# 22  B70AF11248C00F7D4339079310F8B3F1     8  force_replace               False
# 23  B7AE522248AD2604FA45489C1B750FBD     3  force_replace               False
# 24  BA38E83548881BF83570CCABE2CB9B4B    39  force_replace               False
# 25  D1D2CE9E43C95905EF6640AA0576FE1C     3  force_replace               False
# 26  D41FC55D4282E9A5C943D9A8670336CF     8  force_replace               False
# 27  D63BE643469DE5784DD83C8F95B8BFE6     3  force_replace               False
# 28  E6A7C8EE4BB767E8380E3A896092C0E6    39  force_replace               False
# 29  92ADD0F84D07AC532AD03BA0F92A836B     8  force_replace               False
# 30  D64C532E4E7FBA74D29A7CA3576F39CF     8  force_replace               False
# 31  F025A94B4C03B6DCEE0F5D9DA825DA67     8  force_replace               False
# 32  468A0FEE408A7F3D71A6EA8F77FFB41C     3  force_replace               False
# 33  76A492374445A79DE945CD991068419C    10  force_replace               False
# 34  EBCB12A0469E6FA5D49800B25B33E0D3    10  force_replace               False
# 35  7DA2E6DD4BF14BAFCCFDB7B5A38BE70E    10  force_replace               False
# 36  7E31364947BC9CB5B49EB39367F0DC1F    10  force_replace               False
# 37  BE16BFE74B63506CA59FE3AA71174916    10  force_replace               False
# 38  C060EF484E1352B26D945CBAF191F2B8     3  force_replace               False
# 39  98EB31B54122FFB738E6E08A2F29421A    55  force_replace               False
# 40  632539C14B768DF229839BA100C92474     4  force_replace               False
# 41  4E3A75BB43FF442926F3BDA90528CE47     3  force_replace               False
# 42  E770DC1A46D82DD64C5BB1B31259850A     3  force_replace               False
# 43  72B4E8CD45561AAA899FF993EB3B0A91     3  force_replace               False
# 44  3800967D44B10378A8BB95B4414651D5    18  force_replace               False
# 45  FA0A0620423289A61E3CDDA78B2129BC    18  force_replace               False
#
#     subtype
# 0       779
# 1      2048
# 2       779
# 3      2048
# 4      2048
# 5      2048
# 6       779
# 7      2568
# 8      2568
# 9       779
# 10      768
# 11     2566
# 12     2048
# 13      779
# 14      779
# 15      256
# 16      779
# 17     2566
# 18      779
# 19     2048
# 20     2048
# 21      779
# 22     2048
# 23      779
# 24     9984
# 25      779
# 26     2048
# 27      776
# 28     9984
# 29     2048
# 30     2048
# 31     2048
# 32      779
# 33     2567
# 34     2567
# 35     2567
# 36     2567
# 37     2567
# 38      768
# 39    14081
# 40     1024
# 41      776
# 42      776
# 43      776
# 44     4608
# 45     4608

# %% [markdown]
# ### save package & migration files

# %%
# Get source path and build target directory
source_path = my_obj_mig.package_info.storage.path

package_info_path = f"{parent_dir}/{target_folder_name}/package_info.txt"
package_info_blob = blob_service_client.get_blob_client(container=container_name, blob=package_info_path)
package_info_blob.upload_blob(str(my_obj_mig.package_info), overwrite=True)
print(f"✓ Uploaded: {package_info_path}")

# Upload migration_info.txt
migration_info_path = f"{parent_dir}/{target_folder_name}/migration_info.txt"
migration_info_blob = blob_service_client.get_blob_client(container=container_name, blob=migration_info_path)
migration_info_blob.upload_blob(str(from_file_mig.import_info), overwrite=True)
print(f"✓ Uploaded: {migration_info_path}")
# Out:
# ✓ Uploaded: mstr/shared/migrations/packages/2026-07-28/tutorial_objects/package_info.txt
# ✓ Uploaded: mstr/shared/migrations/packages/2026-07-28/tutorial_objects/migration_info.txt

# %% [markdown]
# ### Read & Store Object definition

# %%
# Get source path and build target directory
source_path = my_obj_mig.package_info.storage.path
parent_dir = os.path.dirname(source_path)

# Create blob service client
blob_service_client = BlobServiceClient.from_connection_string(connection_string)

# Build target path for object_def.json
obj_def_target_path = f"{parent_dir}/{target_folder_name}/object_def.json"

# Get blob client
obj_def_blob = blob_service_client.get_blob_client(
    container=container_name,
    blob=obj_def_target_path
)

obj_def_l=[]
for obj in package_content_info:
    obj_def=i_read_gen.get_obj_def(conn=source_conn,object_id=obj["id"],obj_type=obj["type"],obj_sub_type=obj["subtype"])
    obj_def_l.append(obj_def)


# Upload object definition JSON
# If obj_def_l is already a list of dicts, convert to JSON string
obj_def_json_str = json.dumps(obj_def_l, indent=2)
obj_def_blob.upload_blob(obj_def_json_str, overwrite=True)

print(f"✓ Uploaded: {obj_def_target_path}")
# Out:
# nicht gemappt
# sub_object_id:2048
# object_id: 9981CB214C79D75EC342A781539A4E5A
# obj_type: 8
# nicht gemappt
# sub_object_id:2048
# object_id: 032A5E114A59D28267BDD8B6D9E58B22
# obj_type: 8
# nicht gemappt
# sub_object_id:2048
# object_id: CF2049E94A0000A16532D39C6D783F1D
# obj_type: 8
# nicht gemappt
# sub_object_id:2048
# object_id: 7F16A4B811E58ED317D50080EFF554EA
# obj_type: 8
# nicht gemappt
# sub_object_id:2048
# object_id: 2B028FBC466C3DC839E1E092FDF4CC56
# obj_type: 8
# nicht gemappt
# sub_object_id:2048
# object_id: 986E6D1A427030A710A0E68F74290482
# obj_type: 8
# nicht gemappt
# sub_object_id:2048
# object_id: AC7CC55242A3512A1709BD8EB9A7A73A
# obj_type: 8
# nicht gemappt
# sub_object_id:2048
# object_id: B70AF11248C00F7D4339079310F8B3F1
# obj_type: 8
# Error reading object definition
# object_id: BA38E83548881BF83570CCABE2CB9B4B
# obj_type: 39
# obj_sub_type: 9984
# nicht gemappt
# sub_object_id:2048
# object_id: D41FC55D4282E9A5C943D9A8670336CF
# obj_type: 8
# Error reading object definition
# object_id: E6A7C8EE4BB767E8380E3A896092C0E6
# obj_type: 39
# obj_sub_type: 9984
# nicht gemappt
# sub_object_id:2048
# object_id: 92ADD0F84D07AC532AD03BA0F92A836B
# obj_type: 8
# nicht gemappt
# sub_object_id:2048
# object_id: D64C532E4E7FBA74D29A7CA3576F39CF
# obj_type: 8
# nicht gemappt
# sub_object_id:2048
# object_id: F025A94B4C03B6DCEE0F5D9DA825DA67
# obj_type: 8
# nicht gemappt
# sub_object_id:4608
# object_id: 3800967D44B10378A8BB95B4414651D5
# obj_type: 18
# nicht gemappt
# sub_object_id:4608
# object_id: FA0A0620423289A61E3CDDA78B2129BC
# obj_type: 18
# ✓ Uploaded: mstr/shared/migrations/packages/2026-07-28/tutorial_objects/object_def.json

# %%
source_conn.close()
target_conn.close()
# Out:
# Connection to Strategy Intelligence Server has been closed.
# Connection to Strategy Intelligence Server has been closed.
