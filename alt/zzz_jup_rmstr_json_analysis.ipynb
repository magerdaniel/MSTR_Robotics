# %%
from mstr_robotics.json_analyser import parse_json

from mstr_robotics.navigation import mstr_objects
from mstr_robotics.report import rep, prompts
from mstr_robotics.redis_db import  redis_bi_analysis
import json 
from mstr_robotics.json_analyser import parse_json
from mstr_robotics._helper import msic

os_mcp_folder_str="D:\\shared_drive\\mstr_output\\MCP_data"

user_path="D:\\shared_drive\\Python\\mstr_robotics\\config\\user_d.json"
with open(user_path, 'r') as file:
    user_d = json.load(file)

i_prompts=prompts()
i_rep=rep()
u_perplexity=perplexity()
i_mstr_objects=mstr_objects()
i_msic=msic()
i_parse_json=parse_json()

def open_redis_connection(redis_con_d): 
        i_redis_bi_analysis=redis_bi_analysis( 
                host=redis_con_d["host"],
                port=redis_con_d["port"],
                password=redis_con_d["password"],  # Redis Cloud requires auth
                username=redis_con_d["username"],  # Redis Cloud requires username
                decode_responses=redis_con_d["decode_responses"]
                                )
        return i_redis_bi_analysis   

def get_dependency(i_redis_bi_analysis,object_j,target_keys_l=["id", "key", "objectId"]):
    all_obj_def_d_l=[]
    #all_obj_def_d_l.extend(dossier_j)

    child_obj_keys_d_l=i_parse_json.extract_specific_key_value_pairs(data=object_j, target_keys=target_keys_l, 
                                    prefix="root", all_pairs=None, parent_name="")
    child_obj_keys_l=i_msic.get_key_form_dict_l(dict_l=child_obj_keys_d_l, key="value")

    all_keys_l=child_obj_keys_l
    fetch_keys_l=all_keys_l
    while len(fetch_keys_l)>0:
        child_obj_d_l=i_redis_bi_analysis.fetch_key_list(key_l=fetch_keys_l)
        objects_d_l=check_success_status(child_obj_d_l)
        all_obj_def_d_l.extend(objects_d_l)
        
        child_obj_keys_d_l=i_parse_json.extract_specific_key_value_pairs(data=objects_d_l, target_keys=target_keys_l)
        child_obj_keys_l=i_msic.get_key_form_dict_l(dict_l=child_obj_keys_d_l, key="value")
        fetch_keys_l= list(set(child_obj_keys_l) - set(all_keys_l))
        all_keys_l.extend(child_obj_keys_l)

    return all_obj_def_d_l

def check_success_status(child_obj_d_l):
    object_id_l=[]
    for obj in child_obj_d_l:
        if obj["value"]["status"]=="success":
            if len(obj["value"]["value"])>0:
                object_id_l.append(obj["value"]["value"].copy())


    return object_id_l

redis_env_d={"mstr_dev":{
        "host":"redis-14995.c56.east-us.azure.redns.redis-cloud.com",
        "port":14995,
        "password":"[REMOVED-REDIS-PASSWORD]",  
        "username":"default",  
        "decode_responses":True,
        "project_id":"B7CA92F04B9FAE8D941C3E9B7E0CD754",
        "object_id":"98EB31B54122FFB738E6E08A2F29421A"
},
        "mstr_test":{
        "host":"redis-13092.c282.east-us-mz.azure.redns.redis-cloud.com",
        "port":13092,
        "password":"pzSq7pQas9TFd6gMhcypYC70HRdyyvRv",
        "username":"default",
        "decode_responses":True,
        "project_id":"00F3103E41FF3743A057C3B5313595B7",
        "object_id":"98EB31B54122FFB738E6E08A2F29421A"
}}

redis_con_d=redis_env_d["mstr_test"]

# %%
i_redis_bi_analysis_test=open_redis_connection(redis_con_d=redis_env_d["mstr_test"])
i_redis_bi_analysis_dev=open_redis_connection(redis_con_d=redis_env_d["mstr_dev"])

# %%
dossier_j=i_redis_bi_analysis_test.fetch_key_value("98EB31B54122FFB738E6E08A2F29421A")

get_dependency(i_redis_bi_analysis=i_redis_bi_analysis_dev
               ,object_j=dossier_j
               ,target_keys_l=["id", "key", "objectId"])
# Out:
# [{'id': '98EB31B54122FFB738E6E08A2F29421A',
#   'name': 'Detailed data',
#   'datasets': [{'name': 'Customer Detail report (Dashboard)',
#     'id': 'C060EF484E1352B26D945CBAF191F2B8',
#     'availableObjects': [{'id': '56225F324F17B61AEBD88CA256946C96',
#       'name': 'Customer Address',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'Address',
#         'dataType': 'varChar',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4211D3E4981000E787EC6DE8A4',
#       'name': 'Item',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'integer',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'number'}]},
#      {'id': '6E069E4C11D3E4E41000E887EC6DE8A4',
#       'name': 'Customer Age',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'integer',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'number'}]},
#      {'id': '54BABECD11D59D57C000B28A4CC5F24F',
#       'name': 'Brand',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3911D3E4981000E787EC6DE8A4',
#       'name': 'Customer Birth Date',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'timeStamp',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'date'}]},
#      {'id': '8D679D3511D3E4981000E787EC6DE8A4',
#       'name': 'Call Center',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3F11D3E4981000E787EC6DE8A4',
#       'name': 'Employee',
#       'type': 'attribute',
#       'forms': [{'id': '8D67A52E11D3E4981000E787EC6DE8A4',
#         'name': 'Last Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Employee DESC 1',
#         'baseFormType': 'text'},
#        {'id': '8D67A53211D3E4981000E787EC6DE8A4',
#         'name': 'First Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Employee DESC 2',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4B11D3E4981000E787EC6DE8A4',
#       'name': 'Region',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3A11D3E4981000E787EC6DE8A4',
#       'name': 'Customer City',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '5F0132EE456A636FC8D6E7A59A097AA2',
#       'name': 'Customer Email',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'Customer E-mail',
#         'dataType': 'varChar',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'text'}]},
#      {'id': '4151F1304F00A51EB13BCF84283396BE',
#       'name': 'Customer Gender',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3711D3E4981000E787EC6DE8A4',
#       'name': 'Category',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4F11D3E4981000E787EC6DE8A4',
#       'name': 'Subcategory',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '54BABC8311D59D57C000B28A4CC5F24F',
#       'name': 'Customer State',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3C11D3E4981000E787EC6DE8A4',
#       'name': 'Customer',
#       'type': 'attribute',
#       'forms': [{'id': '8D67A35B11D3E4981000E787EC6DE8A4',
#         'name': 'Last Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Customer DESC 1',
#         'baseFormType': 'text'},
#        {'id': '8D67A35F11D3E4981000E787EC6DE8A4',
#         'name': 'First Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Customer DESC 2',
#         'baseFormType': 'text'}]},
#      {'id': '96ED3EC811D5B117C000E78A4CC5F24F',
#       'name': 'Day',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'timeStamp',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'date'}]},
#      {'id': '8D679D4411D3E4981000E787EC6DE8A4',
#       'name': 'Month',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4511D3E4981000E787EC6DE8A4',
#       'name': 'Month of Year',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4A11D3E4981000E787EC6DE8A4',
#       'name': 'Quarter',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D5111D3E4981000E787EC6DE8A4',
#       'name': 'Year',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'integer',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'number'}]},
#      {'id': '632539C14B768DF229839BA100C92474',
#       'name': 'Cost net net',
#       'type': 'metric'},
#      {'id': '7FD5B69611D5AC76C000D98A4CC5F24F',
#       'name': 'Cost',
#       'type': 'metric'},
#      {'id': '381980B211D40BC8C000C8906B98494F',
#       'name': 'Discount',
#       'type': 'metric'},
#      {'id': '4C051D4F11D3E877C000B3B2D86C964F',
#       'name': 'Freight',
#       'type': 'metric'},
#      {'id': '150349F04560BBA2592D019726DF77DD',
#       'name': 'Gross Revenue',
#       'type': 'metric'},
#      {'id': '4C051DB611D3E877C000B3B2D86C964F',
#       'name': 'Profit',
#       'type': 'metric'},
#      {'id': '4C05177011D3E877C000B3B2D86C964F',
#       'name': 'Revenue',
#       'type': 'metric'}],
#     'rows': [{'id': '56225F324F17B61AEBD88CA256946C96',
#       'name': 'Customer Address',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'Address',
#         'dataType': 'varChar',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4211D3E4981000E787EC6DE8A4',
#       'name': 'Item',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'integer',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'number'}]},
#      {'id': '6E069E4C11D3E4E41000E887EC6DE8A4',
#       'name': 'Customer Age',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'integer',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'number'}]},
#      {'id': '54BABECD11D59D57C000B28A4CC5F24F',
#       'name': 'Brand',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3911D3E4981000E787EC6DE8A4',
#       'name': 'Customer Birth Date',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'timeStamp',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'date'}]},
#      {'id': '8D679D3511D3E4981000E787EC6DE8A4',
#       'name': 'Call Center',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3F11D3E4981000E787EC6DE8A4',
#       'name': 'Employee',
#       'type': 'attribute',
#       'forms': [{'id': '8D67A52E11D3E4981000E787EC6DE8A4',
#         'name': 'Last Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Employee DESC 1',
#         'baseFormType': 'text'},
#        {'id': '8D67A53211D3E4981000E787EC6DE8A4',
#         'name': 'First Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Employee DESC 2',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4B11D3E4981000E787EC6DE8A4',
#       'name': 'Region',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3A11D3E4981000E787EC6DE8A4',
#       'name': 'Customer City',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '5F0132EE456A636FC8D6E7A59A097AA2',
#       'name': 'Customer Email',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'Customer E-mail',
#         'dataType': 'varChar',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'text'}]},
#      {'id': '4151F1304F00A51EB13BCF84283396BE',
#       'name': 'Customer Gender',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3711D3E4981000E787EC6DE8A4',
#       'name': 'Category',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4F11D3E4981000E787EC6DE8A4',
#       'name': 'Subcategory',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '54BABC8311D59D57C000B28A4CC5F24F',
#       'name': 'Customer State',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3C11D3E4981000E787EC6DE8A4',
#       'name': 'Customer',
#       'type': 'attribute',
#       'forms': [{'id': '8D67A35B11D3E4981000E787EC6DE8A4',
#         'name': 'Last Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Customer DESC 1',
#         'baseFormType': 'text'},
#        {'id': '8D67A35F11D3E4981000E787EC6DE8A4',
#         'name': 'First Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Customer DESC 2',
#         'baseFormType': 'text'}]},
#      {'id': '96ED3EC811D5B117C000E78A4CC5F24F',
#       'name': 'Day',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'timeStamp',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'date'}]},
#      {'id': '8D679D4411D3E4981000E787EC6DE8A4',
#       'name': 'Month',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4511D3E4981000E787EC6DE8A4',
#       'name': 'Month of Year',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4A11D3E4981000E787EC6DE8A4',
#       'name': 'Quarter',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D5111D3E4981000E787EC6DE8A4',
#       'name': 'Year',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'integer',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'number'}]}],
#     'columns': [{'id': '00000000000000000000000000000000',
#       'name': 'Metrics',
#       'type': 'templateMetrics',
#       'elements': [{'name': 'Cost net net',
#         'id': '632539C14B768DF229839BA100C92474',
#         'type': 'metric',
#         'dataType': 'reserved'},
#        {'name': 'Cost',
#         'id': '7FD5B69611D5AC76C000D98A4CC5F24F',
#         'type': 'metric',
#         'dataType': 'unknown'},
#        {'name': 'Discount',
#         'id': '381980B211D40BC8C000C8906B98494F',
#         'type': 'metric',
#         'dataType': 'unknown'},
#        {'name': 'Freight',
#         'id': '4C051D4F11D3E877C000B3B2D86C964F',
#         'type': 'metric',
#         'dataType': 'unknown'},
#        {'name': 'Gross Revenue',
#         'id': '150349F04560BBA2592D019726DF77DD',
#         'type': 'metric',
#         'dataType': 'unknown'},
#        {'name': 'Profit',
#         'id': '4C051DB611D3E877C000B3B2D86C964F',
#         'type': 'metric',
#         'dataType': 'unknown'},
#        {'name': 'Revenue',
#         'id': '4C05177011D3E877C000B3B2D86C964F',
#         'type': 'metric',
#         'dataType': 'unknown'}]}],
#     'pageBy': []}],
#   'currentChapter': 'K36',
#   'chapters': [{'key': 'K36',
#     'name': 'Data',
#     'pages': [{'key': 'K53',
#       'name': 'Sortiment',
#       'visualizations': [{'key': 'K52',
#         'name': 'Assortment',
#         'visualizationType': 'grid',
#         'selector': {'visualizationKey': 'K52',
#          'selectorType': 'visualization_as_filter',
#          'targets': [{'key': 'W116'}, {'key': 'W119'}],
#          'currentSelection': {'selectionStatus': 'included'}}},
#        {'key': 'W116',
#         'name': 'Others',
#         'visualizationType': 'grid',
#         'selector': {'visualizationKey': 'W116',
#          'selectorType': 'visualization_as_filter',
#          'targets': [{'key': 'W123'}],
#          'currentSelection': {'selectionStatus': 'included'}}},
#        {'key': 'W119',
#         'name': 'Assortment copy 1',
#         'visualizationType': 'grid'},
#        {'key': 'W123',
#         'name': 'Assortment copy copy',
#         'visualizationType': 'grid'}],
#       'selectors': [{'key': 'W138',
#         'name': 'Month',
#         'summary': '',
#         'source': {'id': '8D679D4411D3E4981000E787EC6DE8A4',
#          'name': 'Month',
#          'type': 12},
#         'selectorType': 'attribute_element_list',
#         'displayStyle': 'hyper_links',
#         'hasAllOption': True,
#         'targets': [{'key': 'K52'},
#          {'key': 'W116'},
#          {'key': 'W119'},
#          {'key': 'W123'}],
#         'multiSelectionAllowed': True,
#         'currentSelection': {'selectionStatus': 'unfiltered',
#          'allSelected': False,
#          'elements': []}},
#        {'key': 'W140',
#         'name': 'Selector 1',
#         'summary': '',
#         'selectorType': 'object_replacement',
#         'displayStyle': 'hyper_links',
#         'hasAllOption': False,
#         'targets': [{'key': 'K52'}, {'key': 'W119'}],
#         'multiSelectionAllowed': False,
#         'currentSelection': {'selectionStatus': 'unfiltered',
#          'objectItems': []},
#         'availableObjectItems': [{'id': 'i632539C14B768DF229839BA100C92474;632539C14B768DF229839BA100C92474',
#           'name': 'Cost net net'},
#          {'id': 'i7FD5B69611D5AC76C000D98A4CC5F24F;7FD5B69611D5AC76C000D98A4CC5F24F',
#           'name': 'Cost'},
#          {'id': 'i381980B211D40BC8C000C8906B98494F;381980B211D40BC8C000C8906B98494F',
#           'name': 'Discount'},
#          {'id': 'i4C051D4F11D3E877C000B3B2D86C964F;4C051D4F11D3E877C000B3B2D86C964F',
#           'name': 'Freight'},
#          {'id': 'i150349F04560BBA2592D019726DF77DD;150349F04560BBA2592D019726DF77DD',
#           'name': 'Gross Revenue'},
#          {'id': 'i4C051DB611D3E877C000B3B2D86C964F;4C051DB611D3E877C000B3B2D86C964F',
#           'name': 'Profit'}]},
#        {'key': 'W142',
#         'name': 'Selector 2',
#         'summary': '',
#         'selectorType': 'object_replacement',
#         'displayStyle': 'hyper_links',
#         'hasAllOption': False,
#         'targets': [{'key': 'K52'}, {'key': 'W116'}, {'key': 'W123'}],
#         'multiSelectionAllowed': False,
#         'currentSelection': {'selectionStatus': 'unfiltered',
#          'objectItems': []},
#         'availableObjectItems': [{'id': 'U4151F1304F00A51EB13BCF84283396BE;4151F1304F00A51EB13BCF84283396BE',
#           'name': 'Customer Gender'},
#          {'id': 'U54BABC8311D59D57C000B28A4CC5F24F;54BABC8311D59D57C000B28A4CC5F24F',
#           'name': 'Customer State'},
#          {'id': 'U96ED3EC811D5B117C000E78A4CC5F24F;96ED3EC811D5B117C000E78A4CC5F24F',
#           'name': 'Day'},
#          {'id': 'U8D679D3F11D3E4981000E787EC6DE8A4;8D679D3F11D3E4981000E787EC6DE8A4',
#           'name': 'Employee'},
#          {'id': 'U8D679D4211D3E4981000E787EC6DE8A4;8D679D4211D3E4981000E787EC6DE8A4',
#           'name': 'Item'},
#          {'id': 'U8D679D4411D3E4981000E787EC6DE8A4;8D679D4411D3E4981000E787EC6DE8A4',
#           'name': 'Month'},
#          {'id': 'U8D679D4511D3E4981000E787EC6DE8A4;8D679D4511D3E4981000E787EC6DE8A4',
#           'name': 'Month of Year'},
#          {'id': 'U8D679D4A11D3E4981000E787EC6DE8A4;8D679D4A11D3E4981000E787EC6DE8A4',
#           'name': 'Quarter'},
#          {'id': 'U8D679D4B11D3E4981000E787EC6DE8A4;8D679D4B11D3E4981000E787EC6DE8A4',
#           'name': 'Region'}]},
#        {'key': 'W148',
#         'name': 'Revenue_c',
#         'summary': '',
#         'source': {'id': '4C05177011D3E877C000B3B2D86C964F',
#          'name': 'Revenue',
#          'type': 4},
#         'selectorType': 'metric_qualification',
#         'displayStyle': 'metric_slider',
#         'hasAllOption': True,
#         'targets': [{'key': 'K52'}, {'key': 'W116'}, {'key': 'W119'}],
#         'multiSelectionAllowed': True,
#         'currentSelection': {'selectionStatus': 'unfiltered'}}]},
#      {'key': 'W62',
#       'name': 'Time',
#       'visualizations': [{'key': 'W63',
#         'name': 'Timeseries',
#         'visualizationType': 'grid'}]},
#      {'key': 'W64',
#       'name': 'SalesOrg',
#       'visualizations': [{'key': 'W65',
#         'name': 'Visualization 1',
#         'visualizationType': 'grid'}]},
#      {'key': 'W66',
#       'name': 'Customer',
#       'visualizations': [{'key': 'W67',
#         'name': 'Customer',
#         'visualizationType': 'grid',
#         'selector': {'visualizationKey': 'W67',
#          'selectorType': 'visualization_as_filter',
#          'targets': [{'key': 'W68'}],
#          'currentSelection': {'selectionStatus': 'included',
#           'expression': {'operator': 'Or',
#            'operands': [{'operator': 'In',
#              'operands': [{'type': 'attribute',
#                'id': '8D679D3C11D3E4981000E787EC6DE8A4',
#                'name': 'Customer'},
#               {'type': 'elements',
#                'elements': [{'id': '8D679D3C11D3E4981000E787EC6DE8A4:9627',
#                  'name': 'Adjei'}]}]}]}}}},
#        {'key': 'W68',
#         'name': 'Visualization 1',
#         'visualizationType': 'grid'}]}],
#     'filters': [{'key': 'W125',
#       'name': 'Call Center',
#       'summary': '',
#       'source': {'id': '8D679D3511D3E4981000E787EC6DE8A4',
#        'name': 'Call Center',
#        'type': 12},
#       'synchronizedAcrossChapter': False,
#       'selectorType': 'attribute_element_list',
#       'displayStyle': 'check_boxes',
#       'hasAllOption': True,
#       'targets': [],
#       'multiSelectionAllowed': True,
#       'currentSelection': {'selectionStatus': 'unfiltered',
#        'allSelected': False,
#        'elements': []}},
#      {'key': 'W127',
#       'name': 'Revenue',
#       'summary': '',
#       'source': {'id': '4C05177011D3E877C000B3B2D86C964F',
#        'name': 'Revenue',
#        'type': 4},
#       'synchronizedAcrossChapter': False,
#       'selectorType': 'metric_qualification',
#       'displayStyle': 'metric_slider',
#       'hasAllOption': True,
#       'targets': [],
#       'multiSelectionAllowed': True,
#       'currentSelection': {'selectionStatus': 'unfiltered'}},
#      {'key': 'W129',
#       'name': 'Profit',
#       'summary': '',
#       'source': {'id': '4C051DB611D3E877C000B3B2D86C964F',
#        'name': 'Profit',
#        'type': 4},
#       'synchronizedAcrossChapter': False,
#       'selectorType': 'metric_qualification',
#       'displayStyle': 'metric_qualification',
#       'hasAllOption': True,
#       'targets': [],
#       'multiSelectionAllowed': True,
#       'currentSelection': {'selectionStatus': 'unfiltered'}},
#      {'key': 'W131',
#       'name': 'Quarter',
#       'summary': '',
#       'source': {'id': '8D679D4A11D3E4981000E787EC6DE8A4',
#        'name': 'Quarter',
#        'type': 12},
#       'synchronizedAcrossChapter': True,
#       'selectorType': 'attribute_element_list',
#       'displayStyle': 'check_boxes',
#       'hasAllOption': True,
#       'targets': [{'key': 'W125'}],
#       'multiSelectionAllowed': True,
#       'currentSelection': {'selectionStatus': 'unfiltered',
#        'allSelected': False,
#        'elements': []}}]},
#    {'key': 'W71',
#     'name': 'Features',
#     'pages': [{'key': 'K85',
#       'name': 'Visuals',
#       'visualizations': [{'key': 'K86',
#         'name': 'Brand',
#         'visualizationType': 'bar_chart'},
#        {'key': 'W72',
#         'name': 'Call Center Report',
#         'visualizationType': 'line_chart'}]},
#      {'key': 'W75',
#       'name': 'Selectors',
#       'visualizations': [{'key': 'K112',
#         'name': 'Brand',
#         'visualizationType': 'bar_chart'},
#        {'key': 'K113',
#         'name': 'Call Center Report',
#         'visualizationType': 'line_chart'}],
#       'selectors': [{'key': 'W77',
#         'name': 'Region',
#         'summary': '',
#         'source': {'id': '8D679D4B11D3E4981000E787EC6DE8A4',
#          'name': 'Region',
#          'type': 12},
#         'selectorType': 'attribute_element_list',
#         'displayStyle': 'hyper_links',
#         'hasAllOption': True,
#         'targets': [{'key': 'K113'}, {'key': 'K112'}],
#         'multiSelectionAllowed': True,
#         'currentSelection': {'selectionStatus': 'unfiltered',
#          'allSelected': False,
#          'elements': []}}]}],
#     'filters': []}],
#   'type': 55,
#   'subtype': 14081},
#  {'id': '98EB31B54122FFB738E6E08A2F29421A',
#   'name': 'Detailed data',
#   'datasets': [{'name': 'Customer Detail report (Dashboard)',
#     'id': 'C060EF484E1352B26D945CBAF191F2B8',
#     'availableObjects': [{'id': '56225F324F17B61AEBD88CA256946C96',
#       'name': 'Customer Address',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'Address',
#         'dataType': 'varChar',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4211D3E4981000E787EC6DE8A4',
#       'name': 'Item',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'integer',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'number'}]},
#      {'id': '6E069E4C11D3E4E41000E887EC6DE8A4',
#       'name': 'Customer Age',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'integer',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'number'}]},
#      {'id': '54BABECD11D59D57C000B28A4CC5F24F',
#       'name': 'Brand',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3911D3E4981000E787EC6DE8A4',
#       'name': 'Customer Birth Date',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'timeStamp',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'date'}]},
#      {'id': '8D679D3511D3E4981000E787EC6DE8A4',
#       'name': 'Call Center',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3F11D3E4981000E787EC6DE8A4',
#       'name': 'Employee',
#       'type': 'attribute',
#       'forms': [{'id': '8D67A52E11D3E4981000E787EC6DE8A4',
#         'name': 'Last Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Employee DESC 1',
#         'baseFormType': 'text'},
#        {'id': '8D67A53211D3E4981000E787EC6DE8A4',
#         'name': 'First Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Employee DESC 2',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4B11D3E4981000E787EC6DE8A4',
#       'name': 'Region',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3A11D3E4981000E787EC6DE8A4',
#       'name': 'Customer City',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '5F0132EE456A636FC8D6E7A59A097AA2',
#       'name': 'Customer Email',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'Customer E-mail',
#         'dataType': 'varChar',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'text'}]},
#      {'id': '4151F1304F00A51EB13BCF84283396BE',
#       'name': 'Customer Gender',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3711D3E4981000E787EC6DE8A4',
#       'name': 'Category',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4F11D3E4981000E787EC6DE8A4',
#       'name': 'Subcategory',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '54BABC8311D59D57C000B28A4CC5F24F',
#       'name': 'Customer State',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3C11D3E4981000E787EC6DE8A4',
#       'name': 'Customer',
#       'type': 'attribute',
#       'forms': [{'id': '8D67A35B11D3E4981000E787EC6DE8A4',
#         'name': 'Last Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Customer DESC 1',
#         'baseFormType': 'text'},
#        {'id': '8D67A35F11D3E4981000E787EC6DE8A4',
#         'name': 'First Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Customer DESC 2',
#         'baseFormType': 'text'}]},
#      {'id': '96ED3EC811D5B117C000E78A4CC5F24F',
#       'name': 'Day',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'timeStamp',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'date'}]},
#      {'id': '8D679D4411D3E4981000E787EC6DE8A4',
#       'name': 'Month',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4511D3E4981000E787EC6DE8A4',
#       'name': 'Month of Year',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4A11D3E4981000E787EC6DE8A4',
#       'name': 'Quarter',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D5111D3E4981000E787EC6DE8A4',
#       'name': 'Year',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'integer',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'number'}]},
#      {'id': '632539C14B768DF229839BA100C92474',
#       'name': 'Cost net net',
#       'type': 'metric'},
#      {'id': '7FD5B69611D5AC76C000D98A4CC5F24F',
#       'name': 'Cost',
#       'type': 'metric'},
#      {'id': '381980B211D40BC8C000C8906B98494F',
#       'name': 'Discount',
#       'type': 'metric'},
#      {'id': '4C051D4F11D3E877C000B3B2D86C964F',
#       'name': 'Freight',
#       'type': 'metric'},
#      {'id': '150349F04560BBA2592D019726DF77DD',
#       'name': 'Gross Revenue',
#       'type': 'metric'},
#      {'id': '4C051DB611D3E877C000B3B2D86C964F',
#       'name': 'Profit',
#       'type': 'metric'},
#      {'id': '4C05177011D3E877C000B3B2D86C964F',
#       'name': 'Revenue',
#       'type': 'metric'}],
#     'rows': [{'id': '56225F324F17B61AEBD88CA256946C96',
#       'name': 'Customer Address',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'Address',
#         'dataType': 'varChar',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4211D3E4981000E787EC6DE8A4',
#       'name': 'Item',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'integer',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'number'}]},
#      {'id': '6E069E4C11D3E4E41000E887EC6DE8A4',
#       'name': 'Customer Age',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'integer',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'number'}]},
#      {'id': '54BABECD11D59D57C000B28A4CC5F24F',
#       'name': 'Brand',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3911D3E4981000E787EC6DE8A4',
#       'name': 'Customer Birth Date',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'timeStamp',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'date'}]},
#      {'id': '8D679D3511D3E4981000E787EC6DE8A4',
#       'name': 'Call Center',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3F11D3E4981000E787EC6DE8A4',
#       'name': 'Employee',
#       'type': 'attribute',
#       'forms': [{'id': '8D67A52E11D3E4981000E787EC6DE8A4',
#         'name': 'Last Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Employee DESC 1',
#         'baseFormType': 'text'},
#        {'id': '8D67A53211D3E4981000E787EC6DE8A4',
#         'name': 'First Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Employee DESC 2',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4B11D3E4981000E787EC6DE8A4',
#       'name': 'Region',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3A11D3E4981000E787EC6DE8A4',
#       'name': 'Customer City',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '5F0132EE456A636FC8D6E7A59A097AA2',
#       'name': 'Customer Email',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'Customer E-mail',
#         'dataType': 'varChar',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'text'}]},
#      {'id': '4151F1304F00A51EB13BCF84283396BE',
#       'name': 'Customer Gender',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3711D3E4981000E787EC6DE8A4',
#       'name': 'Category',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4F11D3E4981000E787EC6DE8A4',
#       'name': 'Subcategory',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '54BABC8311D59D57C000B28A4CC5F24F',
#       'name': 'Customer State',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D3C11D3E4981000E787EC6DE8A4',
#       'name': 'Customer',
#       'type': 'attribute',
#       'forms': [{'id': '8D67A35B11D3E4981000E787EC6DE8A4',
#         'name': 'Last Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Customer DESC 1',
#         'baseFormType': 'text'},
#        {'id': '8D67A35F11D3E4981000E787EC6DE8A4',
#         'name': 'First Name',
#         'dataType': 'varChar',
#         'baseFormCategory': 'Customer DESC 2',
#         'baseFormType': 'text'}]},
#      {'id': '96ED3EC811D5B117C000E78A4CC5F24F',
#       'name': 'Day',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'timeStamp',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'date'}]},
#      {'id': '8D679D4411D3E4981000E787EC6DE8A4',
#       'name': 'Month',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4511D3E4981000E787EC6DE8A4',
#       'name': 'Month of Year',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D4A11D3E4981000E787EC6DE8A4',
#       'name': 'Quarter',
#       'type': 'attribute',
#       'forms': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#         'name': 'DESC',
#         'dataType': 'varChar',
#         'baseFormCategory': 'DESC',
#         'baseFormType': 'text'}]},
#      {'id': '8D679D5111D3E4981000E787EC6DE8A4',
#       'name': 'Year',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#         'name': 'ID',
#         'dataType': 'integer',
#         'baseFormCategory': 'ID',
#         'baseFormType': 'number'}]}],
#     'columns': [{'id': '00000000000000000000000000000000',
#       'name': 'Metrics',
#       'type': 'templateMetrics',
#       'elements': [{'name': 'Cost net net',
#         'id': '632539C14B768DF229839BA100C92474',
#         'type': 'metric',
#         'dataType': 'reserved'},
#        {'name': 'Cost',
#         'id': '7FD5B69611D5AC76C000D98A4CC5F24F',
#         'type': 'metric',
#         'dataType': 'unknown'},
#        {'name': 'Discount',
#         'id': '381980B211D40BC8C000C8906B98494F',
#         'type': 'metric',
#         'dataType': 'unknown'},
#        {'name': 'Freight',
#         'id': '4C051D4F11D3E877C000B3B2D86C964F',
#         'type': 'metric',
#         'dataType': 'unknown'},
#        {'name': 'Gross Revenue',
#         'id': '150349F04560BBA2592D019726DF77DD',
#         'type': 'metric',
#         'dataType': 'unknown'},
#        {'name': 'Profit',
#         'id': '4C051DB611D3E877C000B3B2D86C964F',
#         'type': 'metric',
#         'dataType': 'unknown'},
#        {'name': 'Revenue',
#         'id': '4C05177011D3E877C000B3B2D86C964F',
#         'type': 'metric',
#         'dataType': 'unknown'}]}],
#     'pageBy': []}],
#   'currentChapter': 'K36',
#   'chapters': [{'key': 'K36',
#     'name': 'Data',
#     'pages': [{'key': 'K53',
#       'name': 'Sortiment',
#       'visualizations': [{'key': 'K52',
#         'name': 'Assortment',
#         'visualizationType': 'grid',
#         'selector': {'visualizationKey': 'K52',
#          'selectorType': 'visualization_as_filter',
#          'targets': [{'key': 'W116'}, {'key': 'W119'}],
#          'currentSelection': {'selectionStatus': 'included'}}},
#        {'key': 'W116',
#         'name': 'Others',
#         'visualizationType': 'grid',
#         'selector': {'visualizationKey': 'W116',
#          'selectorType': 'visualization_as_filter',
#          'targets': [{'key': 'W123'}],
#          'currentSelection': {'selectionStatus': 'included'}}},
#        {'key': 'W119',
#         'name': 'Assortment copy 1',
#         'visualizationType': 'grid'},
#        {'key': 'W123',
#         'name': 'Assortment copy copy',
#         'visualizationType': 'grid'}],
#       'selectors': [{'key': 'W138',
#         'name': 'Month',
#         'summary': '',
#         'source': {'id': '8D679D4411D3E4981000E787EC6DE8A4',
#          'name': 'Month',
#          'type': 12},
#         'selectorType': 'attribute_element_list',
#         'displayStyle': 'hyper_links',
#         'hasAllOption': True,
#         'targets': [{'key': 'K52'},
#          {'key': 'W116'},
#          {'key': 'W119'},
#          {'key': 'W123'}],
#         'multiSelectionAllowed': True,
#         'currentSelection': {'selectionStatus': 'unfiltered',
#          'allSelected': False,
#          'elements': []}},
#        {'key': 'W140',
#         'name': 'Selector 1',
#         'summary': '',
#         'selectorType': 'object_replacement',
#         'displayStyle': 'hyper_links',
#         'hasAllOption': False,
#         'targets': [{'key': 'K52'}, {'key': 'W119'}],
#         'multiSelectionAllowed': False,
#         'currentSelection': {'selectionStatus': 'unfiltered',
#          'objectItems': []},
#         'availableObjectItems': [{'id': 'i632539C14B768DF229839BA100C92474;632539C14B768DF229839BA100C92474',
#           'name': 'Cost net net'},
#          {'id': 'i7FD5B69611D5AC76C000D98A4CC5F24F;7FD5B69611D5AC76C000D98A4CC5F24F',
#           'name': 'Cost'},
#          {'id': 'i381980B211D40BC8C000C8906B98494F;381980B211D40BC8C000C8906B98494F',
#           'name': 'Discount'},
#          {'id': 'i4C051D4F11D3E877C000B3B2D86C964F;4C051D4F11D3E877C000B3B2D86C964F',
#           'name': 'Freight'},
#          {'id': 'i150349F04560BBA2592D019726DF77DD;150349F04560BBA2592D019726DF77DD',
#           'name': 'Gross Revenue'},
#          {'id': 'i4C051DB611D3E877C000B3B2D86C964F;4C051DB611D3E877C000B3B2D86C964F',
#           'name': 'Profit'}]},
#        {'key': 'W142',
#         'name': 'Selector 2',
#         'summary': '',
#         'selectorType': 'object_replacement',
#         'displayStyle': 'hyper_links',
#         'hasAllOption': False,
#         'targets': [{'key': 'K52'}, {'key': 'W116'}, {'key': 'W123'}],
#         'multiSelectionAllowed': False,
#         'currentSelection': {'selectionStatus': 'unfiltered',
#          'objectItems': []},
#         'availableObjectItems': [{'id': 'U4151F1304F00A51EB13BCF84283396BE;4151F1304F00A51EB13BCF84283396BE',
#           'name': 'Customer Gender'},
#          {'id': 'U54BABC8311D59D57C000B28A4CC5F24F;54BABC8311D59D57C000B28A4CC5F24F',
#           'name': 'Customer State'},
#          {'id': 'U96ED3EC811D5B117C000E78A4CC5F24F;96ED3EC811D5B117C000E78A4CC5F24F',
#           'name': 'Day'},
#          {'id': 'U8D679D3F11D3E4981000E787EC6DE8A4;8D679D3F11D3E4981000E787EC6DE8A4',
#           'name': 'Employee'},
#          {'id': 'U8D679D4211D3E4981000E787EC6DE8A4;8D679D4211D3E4981000E787EC6DE8A4',
#           'name': 'Item'},
#          {'id': 'U8D679D4411D3E4981000E787EC6DE8A4;8D679D4411D3E4981000E787EC6DE8A4',
#           'name': 'Month'},
#          {'id': 'U8D679D4511D3E4981000E787EC6DE8A4;8D679D4511D3E4981000E787EC6DE8A4',
#           'name': 'Month of Year'},
#          {'id': 'U8D679D4A11D3E4981000E787EC6DE8A4;8D679D4A11D3E4981000E787EC6DE8A4',
#           'name': 'Quarter'},
#          {'id': 'U8D679D4B11D3E4981000E787EC6DE8A4;8D679D4B11D3E4981000E787EC6DE8A4',
#           'name': 'Region'}]},
#        {'key': 'W148',
#         'name': 'Revenue_c',
#         'summary': '',
#         'source': {'id': '4C05177011D3E877C000B3B2D86C964F',
#          'name': 'Revenue',
#          'type': 4},
#         'selectorType': 'metric_qualification',
#         'displayStyle': 'metric_slider',
#         'hasAllOption': True,
#         'targets': [{'key': 'K52'}, {'key': 'W116'}, {'key': 'W119'}],
#         'multiSelectionAllowed': True,
#         'currentSelection': {'selectionStatus': 'unfiltered'}}]},
#      {'key': 'W62',
#       'name': 'Time',
#       'visualizations': [{'key': 'W63',
#         'name': 'Timeseries',
#         'visualizationType': 'grid'}]},
#      {'key': 'W64',
#       'name': 'SalesOrg',
#       'visualizations': [{'key': 'W65',
#         'name': 'Visualization 1',
#         'visualizationType': 'grid'}]},
#      {'key': 'W66',
#       'name': 'Customer',
#       'visualizations': [{'key': 'W67',
#         'name': 'Customer',
#         'visualizationType': 'grid',
#         'selector': {'visualizationKey': 'W67',
#          'selectorType': 'visualization_as_filter',
#          'targets': [{'key': 'W68'}],
#          'currentSelection': {'selectionStatus': 'included',
#           'expression': {'operator': 'Or',
#            'operands': [{'operator': 'In',
#              'operands': [{'type': 'attribute',
#                'id': '8D679D3C11D3E4981000E787EC6DE8A4',
#                'name': 'Customer'},
#               {'type': 'elements',
#                'elements': [{'id': '8D679D3C11D3E4981000E787EC6DE8A4:9627',
#                  'name': 'Adjei'}]}]}]}}}},
#        {'key': 'W68',
#         'name': 'Visualization 1',
#         'visualizationType': 'grid'}]}],
#     'filters': [{'key': 'W125',
#       'name': 'Call Center',
#       'summary': '',
#       'source': {'id': '8D679D3511D3E4981000E787EC6DE8A4',
#        'name': 'Call Center',
#        'type': 12},
#       'synchronizedAcrossChapter': False,
#       'selectorType': 'attribute_element_list',
#       'displayStyle': 'check_boxes',
#       'hasAllOption': True,
#       'targets': [],
#       'multiSelectionAllowed': True,
#       'currentSelection': {'selectionStatus': 'unfiltered',
#        'allSelected': False,
#        'elements': []}},
#      {'key': 'W127',
#       'name': 'Revenue',
#       'summary': '',
#       'source': {'id': '4C05177011D3E877C000B3B2D86C964F',
#        'name': 'Revenue',
#        'type': 4},
#       'synchronizedAcrossChapter': False,
#       'selectorType': 'metric_qualification',
#       'displayStyle': 'metric_slider',
#       'hasAllOption': True,
#       'targets': [],
#       'multiSelectionAllowed': True,
#       'currentSelection': {'selectionStatus': 'unfiltered'}},
#      {'key': 'W129',
#       'name': 'Profit',
#       'summary': '',
#       'source': {'id': '4C051DB611D3E877C000B3B2D86C964F',
#        'name': 'Profit',
#        'type': 4},
#       'synchronizedAcrossChapter': False,
#       'selectorType': 'metric_qualification',
#       'displayStyle': 'metric_qualification',
#       'hasAllOption': True,
#       'targets': [],
#       'multiSelectionAllowed': True,
#       'currentSelection': {'selectionStatus': 'unfiltered'}},
#      {'key': 'W131',
#       'name': 'Quarter',
#       'summary': '',
#       'source': {'id': '8D679D4A11D3E4981000E787EC6DE8A4',
#        'name': 'Quarter',
#        'type': 12},
#       'synchronizedAcrossChapter': True,
#       'selectorType': 'attribute_element_list',
#       'displayStyle': 'check_boxes',
#       'hasAllOption': True,
#       'targets': [{'key': 'W125'}],
#       'multiSelectionAllowed': True,
#       'currentSelection': {'selectionStatus': 'unfiltered',
#        'allSelected': False,
#        'elements': []}}]},
#    {'key': 'W71',
#     'name': 'Features',
#     'pages': [{'key': 'K85',
#       'name': 'Visuals',
#       'visualizations': [{'key': 'K86',
#         'name': 'Brand',
#         'visualizationType': 'bar_chart'},
#        {'key': 'W72',
#         'name': 'Call Center Report',
#         'visualizationType': 'line_chart'}]},
#      {'key': 'W75',
#       'name': 'Selectors',
#       'visualizations': [{'key': 'K112',
#         'name': 'Brand',
#         'visualizationType': 'bar_chart'},
#        {'key': 'K113',
#         'name': 'Call Center Report',
#         'visualizationType': 'line_chart'}],
#       'selectors': [{'key': 'W77',
#         'name': 'Region',
#         'summary': '',
#         'source': {'id': '8D679D4B11D3E4981000E787EC6DE8A4',
#          'name': 'Region',
#          'type': 12},
#         'selectorType': 'attribute_element_list',
#         'displayStyle': 'hyper_links',
#         'hasAllOption': True,
#         'targets': [{'key': 'K113'}, {'key': 'K112'}],
#         'multiSelectionAllowed': True,
#         'currentSelection': {'selectionStatus': 'unfiltered',
#          'allSelected': False,
#          'elements': []}}]}],
#     'filters': []}],
#   'type': 55,
#   'subtype': 14081},
#  {'information': {'dateCreated': '2024-08-01T15:24:19.360Z',
#    'dateModified': '2025-09-08T16:41:39.814Z',
#    'versionId': '8CB2AE7442E5D3A7E3B230B4867E2A1E',
#    'acg': 255,
#    'primaryLocale': 'en-US',
#    'objectId': 'C060EF484E1352B26D945CBAF191F2B8',
#    'subType': 'report_grid',
#    'name': 'Customer Detail report (Dashboard)'},
#   'sourceType': 'normal',
#   'dataSource': {'dataTemplate': {'units': [{'id': '56225F324F17B61AEBD88CA256946C96',
#       'name': 'Customer Address',
#       'type': 'attribute',
#       'nonAggregatable': False},
#      {'id': '8D679D4211D3E4981000E787EC6DE8A4',
#       'name': 'Item',
#       'type': 'attribute',
#       'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5', 'name': 'ID'}],
#       'nonAggregatable': False},
#      {'id': '6E069E4C11D3E4E41000E887EC6DE8A4',
#       'name': 'Customer Age',
#       'type': 'attribute',
#       'nonAggregatable': False},
#      {'id': '54BABECD11D59D57C000B28A4CC5F24F',
#       'name': 'Brand',
#       'type': 'attribute',
#       'nonAggregatable': False},
#      {'id': '8D679D3911D3E4981000E787EC6DE8A4',
#       'name': 'Customer Birth Date',
#       'type': 'attribute',
#       'nonAggregatable': False},
#      {'id': '8D679D3511D3E4981000E787EC6DE8A4',
#       'name': 'Call Center',
#       'type': 'attribute',
#       'nonAggregatable': False},
#      {'id': '8D679D3F11D3E4981000E787EC6DE8A4',
#       'name': 'Employee',
#       'type': 'attribute',
#       'nonAggregatable': False},
#      {'id': '8D679D4B11D3E4981000E787EC6DE8A4',
#       'name': 'Region',
#       'type': 'attribute',
#       'nonAggregatable': False},
#      {'id': '8D679D3A11D3E4981000E787EC6DE8A4',
#       'name': 'Customer City',
# ...
#       'name': 'ORDER_DETAIL'}]}],
#   'extensions': [],
#   'entryLevel': [{'objectId': '96ED3EC811D5B117C000E78A4CC5F24F',
#     'subType': 'attribute',
#     'name': 'Day'},
#    {'objectId': '3F58258B437F5CE376CB658F89ADB3AB',
#     'subType': 'attribute',
#     'name': 'Days to Ship'},
#    {'objectId': '8D679D3F11D3E4981000E787EC6DE8A4',
#     'subType': 'attribute',
#     'name': 'Employee'},
#    {'objectId': '8D679D4211D3E4981000E787EC6DE8A4',
#     'subType': 'attribute',
#     'name': 'Item'},
#    {'objectId': '8D679D4611D3E4981000E787EC6DE8A4',
#     'subType': 'attribute',
#     'name': 'Order'},
#    {'objectId': '95FA2DC34EC9063FD6C400B4FA8570E0',
#     'subType': 'attribute',
#     'name': 'Phone Usage'}],
#   'dateCreated': '2006-12-16T01:58:53.000Z',
#   'dateModified': '2008-12-23T12:25:27.000Z',
#   'versionId': '9403A1D642B16D304B85C1B38246E809',
#   'acg': 255,
#   'primaryLocale': 'en-US',
#   'subType': 'fact',
#   'name': 'Gross Revenue',
#   'id': '6EA98A164E62D247C14B3EBFA4866411'},
#  {'dataType': {'type': 'double', 'precision': 8, 'scale': -2147483648},
#   'expressions': [{'expressionId': '305819870AFE11D490C800C04F49986B',
#     'expression': {'text': 'rush_charge',
#      'tokens': [{'level': 'resolved',
#        'state': 'initial',
#        'value': 'rush_charge',
#        'type': 'column_reference',
#        'target': {'dateCreated': '2001-01-02T20:48:37.000Z',
#         'dateModified': '2021-12-08T02:31:06.162Z',
#         'versionId': '7610BD44454FDDC0B8BF23A5C35FF0A2',
#         'acg': 255,
#         'primaryLocale': 'en-US',
#         'objectId': '8D6792E511D3E4981000E787EC6DE8A4',
#         'subType': 'column',
#         'name': 'rush_charge'}},
#       {'level': 'resolved',
#        'state': 'initial',
#        'value': '',
#        'type': 'end_of_text'}]},
#     'tables': [{'objectId': '8D6793F211D3E4981000E787EC6DE8A4',
#       'subType': 'logical_table',
#       'name': 'RUSH_ORDER'}]}],
#   'extensions': [],
#   'entryLevel': [{'objectId': '8D679D4611D3E4981000E787EC6DE8A4',
#     'subType': 'attribute',
#     'name': 'Order'}],
#   'dateCreated': '2001-01-02T20:47:21.000Z',
#   'dateModified': '2008-12-23T12:25:27.000Z',
#   'versionId': 'EF11995942B79EDFF5AC90BCDC5C00F0',
#   'acg': 255,
#   'primaryLocale': 'en-US',
#   'subType': 'fact',
#   'name': 'Rush Charge',
#   'id': '3058196311D40AFEC000C8906B98494F'},
#  {'forms': [{'id': '45C11FA478E745FEA08D781CEA190FE5',
#     'name': 'ID',
#     'category': 'ID',
#     'type': 'system',
#     'displayFormat': 'number',
#     'dataType': {'type': 'integer', 'precision': 2, 'scale': -2147483648},
#     'expressions': [{'expressionId': 'A231CB8FD9104CD0A165AF3028D76C03',
#       'expression': {'text': 'promo_type_id',
#        'tokens': [{'level': 'resolved',
#          'state': 'initial',
#          'value': 'promo_type_id',
#          'type': 'column_reference',
#          'target': {'dateCreated': '2001-01-02T20:48:47.000Z',
#           'dateModified': '2021-12-08T02:29:58.208Z',
#           'versionId': '1953C82C32488B813B433EB8034D4817',
#           'acg': 255,
#           'primaryLocale': 'en-US',
#           'objectId': '8D67925411D3E4981000E787EC6DE8A4',
#           'subType': 'column',
#           'name': 'promo_type_id'}},
#         {'level': 'resolved',
#          'state': 'initial',
#          'value': '',
#          'type': 'end_of_text'}]},
#       'tables': [{'objectId': '8D67939211D3E4981000E787EC6DE8A4',
#         'subType': 'logical_table',
#         'name': 'LU_PROMO_TYPE'},
#        {'objectId': '8D67939811D3E4981000E787EC6DE8A4',
#         'subType': 'logical_table',
#         'name': 'LU_PROMOTION'}]}],
#     'alias': 'promo_type_id',
#     'lookupTable': {'objectId': '8D67939211D3E4981000E787EC6DE8A4',
#      'subType': 'logical_table',
#      'name': 'LU_PROMO_TYPE'}},
#    {'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#     'name': 'DESC',
#     'category': 'DESC',
#     'type': 'system',
#     'isMultilingual': True,
#     'displayFormat': 'text',
#     'dataType': {'type': 'fixed_length_string',
#      'precision': 50,
#      'scale': -2147483648},
#     'expressions': [{'expressionId': 'E31096072D5341A1A50D8E4E84C3CEA4',
#       'expression': {'text': 'promo_type_desc',
#        'tokens': [{'level': 'resolved',
#          'state': 'initial',
#          'value': 'promo_type_desc',
#          'type': 'column_reference',
#          'target': {'dateCreated': '2001-01-02T20:48:45.000Z',
#           'dateModified': '2021-12-08T02:29:58.244Z',
#           'versionId': '3AFED7E7C64CD437A3FB6BBF69AB2AEF',
#           'acg': 255,
#           'primaryLocale': 'en-US',
#           'objectId': '8D67925511D3E4981000E787EC6DE8A4',
#           'subType': 'column',
#           'name': 'promo_type_desc'}},
#         {'level': 'resolved',
#          'state': 'initial',
#          'value': '',
#          'type': 'end_of_text'}]},
#       'tables': [{'objectId': '8D67939211D3E4981000E787EC6DE8A4',
#         'subType': 'logical_table',
#         'name': 'LU_PROMO_TYPE'}]}],
#     'alias': 'promo_type_desc',
#     'lookupTable': {'objectId': '8D67939211D3E4981000E787EC6DE8A4',
#      'subType': 'logical_table',
#      'name': 'LU_PROMO_TYPE'}}],
#   'attributeLookupTable': {'objectId': '8D67939211D3E4981000E787EC6DE8A4',
#    'subType': 'logical_table',
#    'name': 'LU_PROMO_TYPE'},
#   'keyForm': {'id': '45C11FA478E745FEA08D781CEA190FE5', 'name': 'ID'},
#   'displays': {'reportDisplays': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#      'name': 'DESC'}],
#    'browseDisplays': [{'id': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#      'name': 'DESC'}]},
#   'sorts': {},
#   'relationships': [{'parent': {'objectId': '81EE8F2548BF9AEAD58684952CE4558B',
#      'subType': 'attribute',
#      'name': 'Promotion Type'},
#     'child': {'objectId': '1B7A3F0249C78AD99C3A05A7274389BC',
#      'subType': 'attribute',
#      'name': 'Promotion'},
#     'relationshipTable': {'objectId': '8D67939811D3E4981000E787EC6DE8A4',
#      'subType': 'logical_table',
#      'name': 'LU_PROMOTION'},
#     'relationshipType': 'one_to_many'}],
#   'nonAggregatable': False,
#   'dateCreated': '2007-01-25T14:34:22.000Z',
#   'dateModified': '2009-01-05T12:03:29.000Z',
#   'versionId': '50EB1DDE4FC5E230BE6357B38C93C3BF',
#   'acg': 255,
#   'primaryLocale': 'en-US',
#   'subType': 'attribute',
#   'name': 'Promotion Type',
#   'id': '81EE8F2548BF9AEAD58684952CE4558B'},
#  {'physicalTable': {'information': {'dateCreated': '2001-01-02T20:48:51.000Z',
#     'dateModified': '2019-10-15T21:19:18.419Z',
#     'versionId': '72A4806011E9EF9170330080EF45D340',
#     'acg': 255,
#     'primaryLocale': 'en-US',
#     'objectId': '8D67911111D3E4981000E787EC6DE8A4',
#     'subType': 'physical_table',
#     'name': 'lu_promo_type'},
#    'tableName': 'lu_promo_type',
#    'columns': [{'information': {'dateCreated': '2001-01-02T20:48:47.000Z',
#       'dateModified': '2021-12-08T02:29:58.208Z',
#       'versionId': '1953C82C32488B813B433EB8034D4817',
#       'acg': 255,
#       'primaryLocale': 'en-US',
#       'objectId': '8D67925411D3E4981000E787EC6DE8A4',
#       'subType': 'column',
#       'name': 'promo_type_id'},
#      'dataType': {'type': 'integer', 'precision': 2, 'scale': -2147483648},
#      'columnName': 'promo_type_id'},
#     {'information': {'dateCreated': '2001-01-02T20:48:45.000Z',
#       'dateModified': '2021-12-08T02:29:58.244Z',
#       'versionId': '3AFED7E7C64CD437A3FB6BBF69AB2AEF',
#       'acg': 255,
#       'primaryLocale': 'en-US',
#       'objectId': '8D67925511D3E4981000E787EC6DE8A4',
#       'subType': 'column',
#       'name': 'promo_type_desc'},
#      'dataType': {'type': 'fixed_length_string',
#       'precision': 50,
#       'scale': -2147483648},
#      'columnName': 'promo_type_desc'},
#     {'information': {'dateCreated': '2008-09-15T15:53:19.000Z',
#       'dateModified': '2021-12-08T02:29:58.281Z',
#       'versionId': '9A25AD245D4E7CD85FD05BB4B8DBA8B6',
#       'acg': 255,
#       'primaryLocale': 'en-US',
#       'objectId': '358C5DC64C31ADCEA688968F39445BFC',
#       'subType': 'column',
#       'name': 'promo_type_desc_de'},
#      'dataType': {'type': 'fixed_length_string',
#       'precision': 50,
#       'scale': -2147483648},
#      'columnName': 'promo_type_desc_de'},
#     {'information': {'dateCreated': '2008-09-15T15:53:19.000Z',
#       'dateModified': '2021-12-08T02:29:58.316Z',
#       'versionId': 'B5544BB73A4E41C68001328063B23400',
#       'acg': 255,
#       'primaryLocale': 'en-US',
#       'objectId': '9048FCD44196CD9A54E4E4904A39472F',
#       'subType': 'column',
#       'name': 'promo_type_desc_fr'},
#      'dataType': {'type': 'fixed_length_string',
#       'precision': 50,
#       'scale': -2147483648},
#      'columnName': 'promo_type_desc_fr'},
#     {'information': {'dateCreated': '2008-09-15T15:53:19.000Z',
#       'dateModified': '2021-12-08T02:29:58.344Z',
#       'versionId': '8288E25A6141D44E05494E8FC78E4380',
#       'acg': 255,
#       'primaryLocale': 'en-US',
#       'objectId': '94DE4001413A195927BB218849F9EFB5',
#       'subType': 'column',
#       'name': 'promo_type_desc_es'},
#      'dataType': {'type': 'fixed_length_string',
#       'precision': 50,
#       'scale': -2147483648},
#      'columnName': 'promo_type_desc_es'},
#     {'information': {'dateCreated': '2008-09-15T15:53:19.000Z',
#       'dateModified': '2021-12-08T02:29:58.396Z',
#       'versionId': '79F2FC75404DC3CBED4F8B986CA3901F',
#       'acg': 255,
#       'primaryLocale': 'en-US',
#       'objectId': '9E5C634142BE8050A439DB83CE96FCC6',
#       'subType': 'column',
#       'name': 'promo_type_desc_it'},
#      'dataType': {'type': 'fixed_length_string',
#       'precision': 50,
#       'scale': -2147483648},
#      'columnName': 'promo_type_desc_it'},
#     {'information': {'dateCreated': '2008-09-15T15:53:20.000Z',
#       'dateModified': '2021-12-08T02:29:58.431Z',
#       'versionId': 'A1AB5431EF499496197CDDBE63EBFA0F',
#       'acg': 255,
#       'primaryLocale': 'en-US',
#       'objectId': '2E4C0FEE4798EF4F0DBA8196E86A84A6',
#       'subType': 'column',
#       'name': 'promo_type_desc_po'},
#      'dataType': {'type': 'fixed_length_string',
#       'precision': 50,
#       'scale': -2147483648},
#      'columnName': 'promo_type_desc_po'},
#     {'information': {'dateCreated': '2008-09-15T15:53:20.000Z',
#       'dateModified': '2021-12-08T02:29:58.464Z',
#       'versionId': '040EF7435E4FCAE718CC0AB209499115',
#       'acg': 255,
#       'primaryLocale': 'en-US',
#       'objectId': 'E94877F34B64CB7BFD3F25AD3953F258',
#       'subType': 'column',
#       'name': 'promo_type_desc_ja'},
#      'dataType': {'type': 'fixed_length_string',
#       'precision': 50,
#       'scale': -2147483648},
#      'columnName': 'promo_type_desc_ja'},
#     {'information': {'dateCreated': '2008-09-15T15:53:20.000Z',
#       'dateModified': '2021-12-08T02:29:58.500Z',
#       'versionId': 'E170ACCD684C279C8B1326955C2322C3',
#       'acg': 255,
#       'primaryLocale': 'en-US',
#       'objectId': '982B4F1B451158C9F0CCFBA4F02F4908',
#       'subType': 'column',
#       'name': 'promo_type_desc_sch'},
#      'dataType': {'type': 'fixed_length_string',
#       'precision': 50,
#       'scale': -2147483648},
#      'columnName': 'promo_type_desc_sch'},
#     {'information': {'dateCreated': '2008-09-15T15:53:20.000Z',
#       'dateModified': '2021-12-08T02:29:58.535Z',
#       'versionId': 'BAC6D5331942DACB0449258D18ED9F30',
#       'acg': 255,
#       'primaryLocale': 'en-US',
#       'objectId': '4FD32D6344F580DE5F532188076F7FF0',
#       'subType': 'column',
#       'name': 'promo_type_desc_ko'},
#      'dataType': {'type': 'fixed_length_string',
#       'precision': 50,
#       'scale': -2147483648},
#      'columnName': 'promo_type_desc_ko'}],
#    'namespace': 'tutorial',
#    'tablePrefix': 'public.',
#    'type': 'normal'},
#   'logicalSize': 2,
#   'isLogicalSizeLocked': False,
#   'isTrueKey': True,
#   'isPartOfPartition': False,
#   'tableKey': [{'objectId': '81EE8F2548BF9AEAD58684952CE4558B',
#     'subType': 'attribute',
#     'name': 'Promotion Type'}],
#   'attributes': [{'forms': [{'formCategory': {'objectId': '45C11FA478E745FEA08D781CEA190FE5',
#        'subType': 'attribute_form_system',
#        'name': 'ID'},
#       'name': 'ID',
#       'dataFormat': 'number',
#       'isKeyForm': True,
#       'lookupTable': {'objectId': '8D67939211D3E4981000E787EC6DE8A4',
#        'subType': 'logical_table',
#        'name': 'LU_PROMO_TYPE'},
#       'expression': {'text': 'promo_type_id'}},
#      {'formCategory': {'objectId': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#        'subType': 'attribute_form_system',
#        'name': 'DESC'},
#       'name': 'DESC',
#       'dataFormat': 'number',
#       'isKeyForm': False,
#       'lookupTable': {'objectId': '8D67939211D3E4981000E787EC6DE8A4',
#        'subType': 'logical_table',
#        'name': 'LU_PROMO_TYPE'},
#       'expression': {'text': 'promo_type_desc'}}],
#     'subType': 'attribute',
#     'name': 'Promotion Type',
#     'id': '81EE8F2548BF9AEAD58684952CE4558B'}],
#   'primaryDataSource': {'objectId': 'A23BBC514D336D5B4FCE919FE19661A3',
#    'subType': 'db_role',
#    'name': 'Tutorial Postgres'},
#   'secondaryDataSources': [],
#   'dateCreated': '2001-01-02T20:47:05.000Z',
#   'dateModified': '2012-06-06T12:12:35.000Z',
#   'versionId': '215230EB4F7089CD0261C1AD12D621AD',
#   'acg': 255,
#   'primaryLocale': 'en-US',
#   'subType': 'logical_table',
#   'name': 'LU_PROMO_TYPE',
#   'id': '8D67939211D3E4981000E787EC6DE8A4'},
#  {'physicalTable': {'information': {'dateCreated': '2006-06-28T10:59:40.000Z',
#     'dateModified': '2019-11-07T22:46:10.485Z',
#     'versionId': '64C6E8BC11EA01B09B530080EF75AF00',
#     'acg': 255,
#     'primaryLocale': 'en-US',
#     'objectId': '27B7AD604F4D393DB9C48889CB3847F0',
#     'subType': 'physical_table',
#     'name': 'LU_CUST_COUNTRY'},
#    'columns': [{'information': {'dateCreated': '2006-06-28T14:36:57.000Z',
#       'dateModified': '2021-12-08T02:28:09.991Z',
#       'versionId': 'BA593A46854FBADCCCF754B9F9CB138C',
#       'acg': 255,
#       'primaryLocale': 'en-US',
#       'objectId': '1FBA0A404A7E5542EAD4C3B588F9A268',
#       'subType': 'column',
#       'name': 'country_id'},
#      'dataType': {'type': 'integer', 'precision': 2, 'scale': -2147483648},
#      'columnName': 'country_id'},
#     {'information': {'dateCreated': '2006-06-28T14:41:21.000Z',
#       'dateModified': '2021-12-08T02:28:15.545Z',
#       'versionId': 'D9BC9498AA411E90B2359CBC58F51F46',
#       'acg': 255,
#       'primaryLocale': 'en-US',
#       'objectId': '095BEED5454B2C9CAD18C9BCE6C68D46',
#       'subType': 'column',
#       'name': 'country_name'},
#      'dataType': {'type': 'fixed_length_string',
#       'precision': 50,
#       'scale': -2147483648},
#      'columnName': 'country_name'}],
#    'sqlStatement': 'SELECT COUNTRY_ID, COUNTRY_NAME\r\nFROM lu_country\r\nWHERE COUNTRY_ID IN (1,3,4,5,6)',
#    'type': 'sql'},
#   'logicalSize': 2,
#   'isLogicalSizeLocked': False,
#   'isTrueKey': True,
#   'isPartOfPartition': False,
#   'tableKey': [{'objectId': 'CE83EF17457F50F005D767864DAF42B7',
#     'subType': 'attribute',
#     'name': 'Customer Country'}],
#   'attributes': [{'forms': [{'formCategory': {'objectId': '45C11FA478E745FEA08D781CEA190FE5',
#        'subType': 'attribute_form_system',
#        'name': 'ID'},
#       'name': 'ID',
#       'dataFormat': 'number',
#       'isKeyForm': True,
#       'lookupTable': {'objectId': '8D6963F745CA85B14D5819921E4F9382',
#        'subType': 'logical_table',
#        'name': 'LU_CUST_COUNTRY'},
#       'expression': {'text': 'country_id'}},
#      {'formCategory': {'objectId': 'CCFBE2A5EADB4F50941FB879CCF1721C',
#        'subType': 'attribute_form_system',
#        'name': 'DESC'},
#       'name': 'DESC',
#       'dataFormat': 'number',
#       'isKeyForm': False,
#       'lookupTable': {'objectId': '8D6963F745CA85B14D5819921E4F9382',
#        'subType': 'logical_table',
#        'name': 'LU_CUST_COUNTRY'},
#       'expression': {'text': 'country_name'}}],
#     'subType': 'attribute',
#     'name': 'Customer Country',
#     'id': 'CE83EF17457F50F005D767864DAF42B7'}],
#   'encloseSqlInParentheses': True,
#   'primaryDataSource': {'objectId': 'A23BBC514D336D5B4FCE919FE19661A3',
#    'subType': 'db_role',
#    'name': 'Tutorial Postgres'},
#   'dateCreated': '2006-06-28T10:59:40.000Z',
#   'dateModified': '2019-11-07T22:46:10.518Z',
#   'versionId': '64CBF60411EA01B000FB0080EF45D067',
#   'acg': 255,
#   'primaryLocale': 'en-US',
#   'subType': 'logical_table',
#   'name': 'LU_CUST_COUNTRY',
#   'id': '8D6963F745CA85B14D5819921E4F9382'}]

# %%
len(all_obj_def_d_l)
#child_obj_d_l=i_redis_bi_analysis.fetch_key_list(key_l=list(set(all_keys_l
#all_obj_def_d_l[2]
# Out:
# 186
