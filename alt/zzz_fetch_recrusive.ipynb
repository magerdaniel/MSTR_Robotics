# %%
import json
from mstr_robotics.redis_db import  redis_bi_analysis, fetch_it_all

redis_env_d={"mstr_dev":{
        "host":"redis-14995.c56.east-us.azure.redns.redis-cloud.com",
        "port":14995,
        "password":"[REMOVED-REDIS-PASSWORD]",  
        "username":"default",  
        "decode_responses":True,
        "project_id":"B7CA92F04B9FAE8D941C3E9B7E0CD754",
        "redis_prefix":"mstr_dev"
},
        "mstr_test":{
        "host":"redis-13092.c282.east-us-mz.azure.redns.redis-cloud.com",
        "port":13092,
        "password":"pzSq7pQas9TFd6gMhcypYC70HRdyyvRv",
        "username":"default",
        "decode_responses":True,
        "project_id":"F8AD06364B29E4FFA3AEC9A34E706A47",
        "redis_prefix":"mstr_test"
}}

# %%
# Simple usage example
# Get all objects starting from specific IDs

redis_con_d=redis_env_d["mstr_dev"]
i_redis_bi_analysis = redis_bi_analysis( 
    host=redis_con_d["host"],
    port=redis_con_d["port"],
    password=redis_con_d["password"],
    username=redis_con_d["username"],
    decode_responses=redis_con_d["decode_responses"]
)
i_fetch_it_all=fetch_it_all(i_redis_bi_analysis)

root_object_id_l = ["mstr_test:FILTER:1ACEE9A511D3E95BC000B3B2D86C964F", "mstr_test:DOCUMENT_DEFINITION:98EB31B54122FFB738E6E08A2F29421A"]
all_objects = i_fetch_it_all.fetch_all_objects_recursively(root_object_id_l)

print(f"Found {len(all_objects)} total objects in hierarchy")
for obj in all_objects:
    print(f"Key: {obj['key']}")
# Out:
# Found 200 total objects in hierarchy
# Key: mstr_test:FILTER:1ACEE9A511D3E95BC000B3B2D86C964F
# Key: mstr_test:DOCUMENT_DEFINITION:98EB31B54122FFB738E6E08A2F29421A
# Key: mstr_test:ATTRIBUTE:8D679D3C11D3E4981000E787EC6DE8A4
# Key: mstr_test:METRIC:4C05177011D3E877C000B3B2D86C964F
# Key: mstr_test:REPORT_DEFINITION:C060EF484E1352B26D945CBAF191F2B8
# Key: mstr_test:ATTRIBUTE:54BABECD11D59D57C000B28A4CC5F24F
# Key: mstr_test:ATTRIBUTE:8D679D3511D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D3711D3E4981000E787EC6DE8A4
# Key: mstr_test:METRIC:632539C14B768DF229839BA100C92474
# Key: mstr_test:METRIC:7FD5B69611D5AC76C000D98A4CC5F24F
# Key: mstr_test:ATTRIBUTE:56225F324F17B61AEBD88CA256946C96
# Key: mstr_test:ATTRIBUTE:6E069E4C11D3E4E41000E887EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D3911D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D3A11D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:5F0132EE456A636FC8D6E7A59A097AA2
# Key: mstr_test:ATTRIBUTE:4151F1304F00A51EB13BCF84283396BE
# Key: mstr_test:ATTRIBUTE:54BABC8311D59D57C000B28A4CC5F24F
# Key: mstr_test:ATTRIBUTE:96ED3EC811D5B117C000E78A4CC5F24F
# Key: mstr_test:METRIC:381980B211D40BC8C000C8906B98494F
# Key: mstr_test:ATTRIBUTE:8D679D3F11D3E4981000E787EC6DE8A4
# Key: mstr_test:METRIC:4C051D4F11D3E877C000B3B2D86C964F
# Key: mstr_test:METRIC:150349F04560BBA2592D019726DF77DD
# Key: mstr_test:ATTRIBUTE:8D679D4211D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D4411D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D4511D3E4981000E787EC6DE8A4
# Key: mstr_test:METRIC:4C051DB611D3E877C000B3B2D86C964F
# Key: mstr_test:ATTRIBUTE:8D679D4A11D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D4B11D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D4F11D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D5111D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D67935611D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:54D82D5B4BD115DA313C03A5742900AE
# Key: mstr_test:TABLE:374BEA694C70098E7549BCAF98272A66
# Key: mstr_test:TABLE:40E8D9C54FEDFBD7D6A19186FCA6631C
# Key: mstr_test:TABLE:FFFA09C4437E6904E0CE2A93EB7911A8
# Key: mstr_test:TABLE:F03781014DE83DB62C566DB22AE5A1E1
# Key: mstr_test:TABLE:8D6793CE11D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D6793D411D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:54BABD9E11D59D57C000B28A4CC5F24F
# Key: mstr_test:ATTRIBUTE:606595154DEEF0EBFB2BAA984562998E
# Key: mstr_test:ATTRIBUTE:846E77494CAFEAAC43BA51986F6EBCBF
# Key: mstr_test:ATTRIBUTE:5603951E4FE1BC04A44E44B85BBB8ED2
# Key: mstr_test:ATTRIBUTE:4E5EAA86422ECC140D612E8F0FD8D4E6
# Key: mstr_test:ATTRIBUTE:824B49C54A0EE1F4441DDC868AA7C61C
# Key: mstr_test:ATTRIBUTE:326CD64840B28B1497ADE09539FEC9C5
# Key: mstr_test:ATTRIBUTE:6DB0057641A6E9B6FE37ACAAD86E81A0
# Key: mstr_test:ATTRIBUTE:4D03EE044D33671811F9ADA6B84668E9
# Key: mstr_test:ATTRIBUTE:8D679D4111D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D4611D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:C9FC43714960586058B015805734E2F8
# Key: mstr_test:ATTRIBUTE:CB3CF9D34B28CF170C60A4873EB55A87
# Key: mstr_test:ATTRIBUTE:D40E5ACA409A88F64BDE4FB2B29646E9
# Key: mstr_test:AGG_METRIC:4C05176211D3E877C000B3B2D86C964F
# Key: mstr_test:PROMPT:31A96A44479DBB67AA74B381CE8348DE
# Key: mstr_test:PROMPT:76A492374445A79DE945CD991068419C
# Key: mstr_test:PROMPT:EBCB12A0469E6FA5D49800B25B33E0D3
# Key: mstr_test:PROMPT:7E31364947BC9CB5B49EB39367F0DC1F
# Key: mstr_test:PROMPT:BE16BFE74B63506CA59FE3AA71174916
# Key: mstr_test:PROMPT:7DA2E6DD4BF14BAFCCFDB7B5A38BE70E
# Key: mstr_test:TABLE:54BAB92B11D59D57C000B28A4CC5F24F
# Key: mstr_test:TABLE:8D67937411D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D67933211D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:862780DC499A14D74FEC7EB2EF317DA2
# Key: mstr_test:TABLE:6F4FF0C84F271FC9851E9F8F502FF1C0
# Key: mstr_test:TABLE:EF5FEFD9469F9F08818B69B995223EC2
# Key: mstr_test:TABLE:980A427E49EA03F02C85E2A95C66F794
# Key: mstr_test:TABLE:8D67936811D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:1C4BF0AE452247D0649F63B845862B19
# Key: mstr_test:ATTRIBUTE:8D679D4311D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D5211D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D67933E11D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D6793B611D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D6793C811D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D6793E611D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D67941611D3E4981000E787EC6DE8A4
# Key: mstr_test:FACT:7A4ABE9111D5AC6FC000D98A4CC5F24F
# Key: mstr_test:TABLE:8D67934A11D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:9A28CFCC42DB8E9627D547975958C138
# Key: mstr_test:TABLE:76C6FEAB49D08F57BC6FC9B644743EEF
# Key: mstr_test:TABLE:D953F9044B9181FB6E0C0090644F991C
# Key: mstr_test:TABLE:54BAB92C11D59D57C000B28A4CC5F24F
# Key: mstr_test:TABLE:8F691B7047CA875A67E6C7811D6EEDB8
# Key: mstr_test:TABLE:167D1CEF4D7151F8BFB13193AAB9B40B
# Key: mstr_test:TABLE:B3B4B2764639C506BF07C8B1DA826CDA
# Key: mstr_test:ATTRIBUTE:8D679D3B11D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:24C30AD611D5AEC9C000E38A4CC5F24F
# Key: mstr_test:TABLE:24C30AD711D5AEC9C000E38A4CC5F24F
# Key: mstr_test:TABLE:8D6793E011D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:EB724EAF4F1C276F026975AD68C214E8
# Key: mstr_test:TABLE:30C485F24394DE7D9FA99689B030C274
# Key: mstr_test:FACT:62AA36C011D3E4EC1000E887EC6DE8A4
# Key: mstr_test:TABLE:1BF908D94C2F9997CCAB39A633525570
# Key: mstr_test:ATTRIBUTE:8D679D3411D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:0726593B4ABFE747CF7A5E8F9906BEB3
# Key: mstr_test:ATTRIBUTE:8D679D4011D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D4C11D3E4981000E787EC6DE8A4
# Key: mstr_test:FACT:8D67958311D3E4981000E787EC6DE8A4
# Key: mstr_test:AGG_METRIC:612EFFCB4AD36E3789E167B0AC8421F7
# Key: mstr_test:TABLE:C24B5636416240634C5CBFB92F763391
# Key: mstr_test:TABLE:8D67932C11D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:929118964740ECCB9DB121A0A60A78B1
# Key: mstr_test:TABLE:8D6793EC11D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D3611D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D3E11D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:3E3ADE2E11D4BB3610004594316DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D5011D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:4F1009614A6646AC93F3F2908D011C32
# Key: mstr_test:TABLE:8D67938011D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:1C0A3D964E21D5D517D915958D284694
# Key: mstr_test:TABLE:8D67938611D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D6793A411D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D6793AA11D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D3811D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D6793C211D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:95FA2DC34EC9063FD6C400B4FA8570E0
# Key: mstr_test:TABLE:ED8A34EC483EA8946D2A248FEF9A116B
# Key: mstr_test:ATTRIBUTE:5B81D4D541A551CCC0535EA54B88B611
# Key: mstr_test:ATTRIBUTE:A85A9D5C4F64009D39EA96812FFFF271
# Key: mstr_test:TABLE:774F53FD4290CBB76FC95EAE70D4A532
# Key: mstr_test:TABLE:6165793240E30799F1FB3391DF87476D
# Key: mstr_test:TABLE:CACF0A72483D645918B5AE85091504E4
# Key: mstr_test:TABLE:8D67936E11D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:0139A31144A93D3FD7216CA4ADBD404F
# Key: mstr_test:TABLE:1D02C5B84DECDA0F6F84808F7AA89617
# Key: mstr_test:FACT:3EB7792442CEFAA2629B3A8A0B724FBE
# Key: mstr_test:FACT:D3A92CE84909866E611CC5B716EFEEBB
# Key: mstr_test:FACT:C937D32D4B4D76282F60B28D14513563
# Key: mstr_test:FACT:6EA98A164E62D247C14B3EBFA4866411
# Key: mstr_test:FACT:F30CB66411D5AC5FC000D98A4CC5F24F
# Key: mstr_test:FACT:8D67958411D3E4981000E787EC6DE8A4
# Key: mstr_test:FACT:8D67958511D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:BD19156D468084094B34FDAE0D9BDB2B
# Key: mstr_test:TABLE:D65C3A92442F070A00C636AFCD51F502
# Key: mstr_test:FACT:FF10A2EE4EEAD7C9BE4A6AA62344303C
# Key: mstr_test:FACT:924B585349683EB511500EBBA5D43CCB
# Key: mstr_test:FACT:9F1CFCBB4440228D160DEF9D541FFB3D
# Key: mstr_test:FACT:D8D3138842DDDAE2DE0E1387407FF581
# Key: mstr_test:ATTRIBUTE:86032238450ADBD4183AA68831B3ED10
# Key: mstr_test:ATTRIBUTE:34C4437241F25EBE06F8DF9168B63019
# Key: mstr_test:ATTRIBUTE:2F3EA82A493213DE1DEB6CBE69E5C0D6
# Key: mstr_test:ATTRIBUTE:C92DE1FE4946CC8A9FC07C8C9266FC41
# Key: mstr_test:TABLE:8D67939811D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:1B7A3F0249C78AD99C3A05A7274389BC
# Key: mstr_test:FACT:62AA362011D3E4EC1000E887EC6DE8A4
# Key: mstr_test:FACT:8D67958611D3E4981000E787EC6DE8A4
# Key: mstr_test:FACT:3E3AE5E511D4BB3610004594316DE8A4
# Key: mstr_test:FACT:62AA35D111D3E4EC1000E887EC6DE8A4
# Key: mstr_test:ATTRIBUTE:3F58258B437F5CE376CB658F89ADB3AB
# Key: mstr_test:TABLE:8D67939E11D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D4911D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D4D11D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D6793B011D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:8D679D4E11D3E4981000E787EC6DE8A4
# Key: mstr_test:FACT:62AA364F11D3E4EC1000E887EC6DE8A4
# Key: mstr_test:TABLE:8D6793F211D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:A2AFB70811D3E4A81000E787EC6DE8A4
# Key: mstr_test:TABLE:8D6793BC11D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:F9EB7AE74085FCE6CF52299BD9642F66
# Key: mstr_test:TABLE:8D67934411D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D67936211D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D67937A11D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:A1B447524B4C8E77D547B795A51179A2
# Key: mstr_test:FACT:F0B5CE694B42895AC7EE4C81433BD6D3
# Key: mstr_test:FACT:E60E0B8843B9925BFA4DE889F7E42EF6
# Key: mstr_test:FACT:9D4ACBB240DFEFFC1E94B8BAA2E4DC0B
# Key: mstr_test:FACT:F44AA4E34CADBE24A5084AB550B5FD6A
# Key: mstr_test:ATTRIBUTE:6E069EA411D3E4E41000E887EC6DE8A4
# Key: mstr_test:ATTRIBUTE:B793B43811D3E4E51000E887EC6DE8A4
# Key: mstr_test:TABLE:47EED4464642E1C0D5353BAB74D9A3D6
# Key: mstr_test:ATTRIBUTE:2501818A4033B34A5FCD3FBCC8F7F30F
# Key: mstr_test:FACT:83CFA98A4E48E09C33B8449FDAE03260
# Key: mstr_test:TABLE:8D67935011D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:CE83EF17457F50F005D767864DAF42B7
# Key: mstr_test:FACT:4E01932F11D4F6D4C0004F916B98494F
# Key: mstr_test:FACT:DB15DA8A4A7510DB1FB168B758C132E7
# Key: mstr_test:FACT:3103680A41C81E81EC3079BD44126F09
# Key: mstr_test:FACT:C3290F0740F46D7F3DA4BA84FD590B92
# Key: mstr_test:FACT:6C745A2011D5BCEEC000F88A4CC5F24F
# Key: mstr_test:FACT:8D67958811D3E4981000E787EC6DE8A4
# Key: mstr_test:TABLE:8D67933811D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:69433E1148DF77B4B4BB61A8AED0D630
# Key: mstr_test:ATTRIBUTE:521BE8C647086380AF61F8AB291E7C2A
# Key: mstr_test:ATTRIBUTE:608478A64524FCF99F4C82B9B259CA06
# Key: mstr_test:ATTRIBUTE:06AEB69B4D7AA3401C9A6AB345826D26
# Key: mstr_test:ATTRIBUTE:9AF41096461C91D06E417298B9BB8877
# Key: mstr_test:ATTRIBUTE:D7626C8C460177307A9C3DAE98F91B31
# Key: mstr_test:ATTRIBUTE:F9A3E5F24D2AAFAE353738A98E1089FE
# Key: mstr_test:ATTRIBUTE:FD6CEC8F4CB442F344E81CBCA586E923
# Key: mstr_test:FACT:FEDCF3A5404E070D3CBDA2A1DE70A804
# Key: mstr_test:FACT:3430C6964362B68D3D0BE8AA296111CF
# Key: mstr_test:FACT:6C7459FC11D5BCEEC000F88A4CC5F24F
# Key: mstr_test:TABLE:7D4BF0F645FCFCE820769B815E3987EC
# Key: mstr_test:TABLE:B05690604B9CD8BFEAF2FB866ED1F7FE
# Key: mstr_test:ATTRIBUTE:073BECDD442A1DDF77C7CA9D420DCE1D
# Key: mstr_test:ATTRIBUTE:AEDB54DF4722DE13C229D69BBD9E8CC1
# Key: mstr_test:FACT:6C7459CE11D5BCEEC000F88A4CC5F24F
# Key: mstr_test:TABLE:8D67939211D3E4981000E787EC6DE8A4
# Key: mstr_test:ATTRIBUTE:81EE8F2548BF9AEAD58684952CE4558B
# Key: mstr_test:FACT:3058196311D40AFEC000C8906B98494F
# Key: mstr_test:TABLE:8D6963F745CA85B14D5819921E4F9382

# %%
for o in all_objects:
    if o["definition"]==None:
        print(o["key"])

# %%
all_objects

# %%
class x_fetch_it_all:

    def __init__(self, i_redis_bi_analysis):
        self.i_redis_bi_analysis=i_redis_bi_analysis
    
    def fetch_all_objects_recursively(self, root_object_keys, visited_objects=None):
        """
        Recursively fetch all object definitions from Redis based on child references
        
        Args:

            root_object_keys: List of initial object keys to start with
            visited_objects: Set to track already processed objects (prevents infinite loops)
            
        Returns:
            List of all object definitions (dictionaries)
        """
        if visited_objects is None:
            visited_objects = set()
        
        all_objects = []
        objects_to_process = list(root_object_keys)
        
        while objects_to_process:
            current_key = objects_to_process.pop(0)
            
            # Skip if already processed
            if current_key in visited_objects:
                continue
                
            visited_objects.add(current_key)
            
            try:
                # Fetch object definition from Redis
                obj_def = self.i_redis_bi_analysis.fetch_key_value(current_key)["value"]
                                   
                # Add current object to results
                all_objects.append({
                    'key': current_key,
                    'definition': obj_def
                })
                
                # Extract child object references
                child_keys = self.extract_child_object_keys(obj_def)
                
                # Add child keys to processing queue
                for child_key in child_keys:
                    if child_key not in visited_objects:
                        objects_to_process.append(child_key)
                        
            except Exception as e:
                print(f"Error processing object {current_key}: {e}")
                continue
        
        return all_objects

    def extract_child_object_keys(self, obj_def):
        """
        Extract child object keys from the object definition
        
        Args:
            obj_def: Object definition dictionary
            
        Returns:
            List of child object keys
        """
        child_keys = []
        
        try:
            # Navigate to child_obj_d_l.prefix_child_d_l
            if 'child_obj_d_l' in obj_def:
                child_obj_d_l = obj_def['child_obj_d_l']
                
                if isinstance(child_obj_d_l, dict) and 'prefix_child_d_l' in child_obj_d_l:
                    prefix_child_d_l = child_obj_d_l['prefix_child_d_l']
                    
                    for child_ref in prefix_child_d_l:
                        child_keys.append(child_ref["redis_key"])
                                
        except Exception as e:
            print(f"Error extracting child keys: {e}")
        
        return child_keys

    def fetch_complete_object_hierarchy(self,  root_object_id_l, env_prefix):
        """
        Main function to fetch complete object hierarchy from Redis
        
        Args:
     
            initial_object_ids: List of object IDs to start with
            env_prefix: Environment prefix for Redis keys
            
        Returns:
            List of all related object definitions
        """
       
        # Fetch all objects recursively
        all_objects = self.fetch_all_objects_recursively(

            root_object_keys=root_object_id_l
        )
        
        return all_objects


    # Usage example with your existing Redis setup
    def get_all_related_objects(self,root_object_id_l, env_prefix="mstr_dev"):
        """
        Get all related objects for a list of object IDs
        
        Args:
            object_ids: List of object IDs to start with
            env_prefix: Environment prefix for Redis keys
            
        Returns:
            List of all related object definitions
        """
        # Use your existing Redis connection
        
        # Fetch complete hierarchy
        all_objects = self.fetch_complete_object_hierarchy(
            
            root_object_id_l=root_object_id_l,
            env_prefix=env_prefix
        )
        
        return all_objects

# %%
len(all_objects)
